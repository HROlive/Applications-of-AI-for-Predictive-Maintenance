# %% [markdown]
# <img src="images/header.png" alt="Header" style="width: 400px;"/>
# <h1 align="center">Predictive Maintenance using NVIDIA RAPIDS and Deep Learning Models</h1>
# <h4 align="center">Part 3: Training Autoencoder for Anomaly Detection</h4>

# %% [markdown]
# ## Overview

# %% [markdown]
# In the previous lab, we used LSTMs to predict hard drive failures. While timeseries prediction is a very well-studied approach in predictive maintenance, in this section we focus on a different deep learning technique, which is called __anomaly detection__. In a nutshell, considering the fact that only a small portion of the hard drives are defective in our use case, we can treat those as anomalies. For example, out of three million samples we dealt with in our training set within the previous lab, only 256 samples were defective. Those are "anomalies" among the big pool of well-functioning hard drives. Now, if we could have a model capable of learning what a proper functioning hard drive looks like, it could detect hard drives with a different behavior pattern.
#
#
# This lab covers the following topics:
#
# * [Autoencoders](#1)
#     * [Exercise 1: Retrieve the output labels](#e1)
#     * [Exercise 2: Filtering the labels](#e2)
#     * [Testing Models](#2)
#         * [LSTM Autoencoder Model](#3)
#         * [1D Convolution Model](#3b)
# * [Hyperparameter Optimization](#e4)
#     * [Exercise 3: Experimenting with Hyperparameters](#e4)
#     * [Exercise 4: Update code to use specified validation data](#e5)
#     * [Exercise 5: Create HPO result plots](#e6)
#
# In this lab, we will leverage the same Backblaze Hard Drive SMART data to train an Autoencoder model that will detect anomaly activity.  We'll leverage the time series sequences that we created in the previous step to train an Autoencoder Model to identify when there are significant variances from expected sensor data.  These variances can be used to alert support teams that there are potential issues with the system.
#
# You'll see that autoencoders (AEs) are relatively easy to use, but let's first walk through the basics of using autoencoders.
#
# We can use unsupervised learning algorithms like a deep autoencoder network to perform anomaly detection. A deep autoencoder takes an input X and attempts to map it back to itself; in essence, the autoencoder is trying to learn the identity function of the input data. Since learning the identity function is pretty trivial, we force the hidden layers of our autoencoder to be of lower dimensionality than the previous layer. This constraint forces the autoencoder to learn patterns in the data, and really learn efficient representations.
#
# <img src="img/AE_img-2.png" style="margin-top:10px;"/>
# <p style="text-align: center;color:gray"> Figure 1. Using an autoencoder to map a timeseries data back to itself</p>
#
# To train this type of neural network, we can calculate the difference between the input and the output and use that loss, typically called a reconstruction loss, as our loss function for training our model. The idea is that our autoencoder is essentially learning the data generating distribution for a unique dataset, and when we feed data generated from a different distribution into our autoencoder, our autoencoder will do a very poor job of reconstructing the input from the second source and our reconstruction error will be high; this indicates that our input is anomalous instead of just an extreme value.
#
# <img src="img/AE_img-3.png" style="margin-top:10px;"/>
# <p style="text-align: center;color:gray"> Figure 2. The predicted and ground-truth timeseries comparison after applying the autoencoder</p>

# %% [markdown]
# <a name="1"></a>
# ## Autoencoders

# %% [markdown]
# Autoencoders are a subset of neural network architectures where the output dimension is the same as the input dimension. Autoencoders have two networks, an encoder and a decoder.  The encoder encodes its input data into a smaller dimensional space, called the latent space.  The decoder network tries to reconstruct the original data from the latent encoding. Typically, the encoder and decoder are symmetric, and the latent space is a bottleneck. The autoencoder has to learn essential characteristics of the data to be able to do a high-quality reconstruction of the data during decode.
#
#
#
# <img src="img/AE_img-1.png" style="margin-top:10px;"/>
# <p style="text-align: center;color:gray"> Figure 3.  Structure of an auto-encoder model</p>
#
# Autoencoders can be built using many different layer types based on the desire goal of the model.  In this lab, we'll experiment using two different autoencoder models.  One built with LSTM layers and one built on top of 1D-Convolution.  You'll have the opportunity to test both.  Additionally, you'll see that we leverage Dropout layers as a way to control overfitting by randomly omitting subsets of features at each iteration of a training procedure. To begin, let’s import some libraries that we are going to use throughout this lab.

# %%
# Import libraries that will be needed for the lab
import os
import sys
import time
import logging
import importlib
import numpy as np
import pandas as pd
import collections
from tqdm import tqdm

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc,precision_recall_fscore_support, average_precision_score, precision_recall_curve, auc, confusion_matrix,accuracy_score

from tensorflow.keras import initializers, regularizers
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Input, LSTM, BatchNormalization, LeakyReLU, Dense, Reshape, Flatten, Dropout, multiply, GaussianNoise, MaxPooling2D, concatenate

from tensorflow.keras import backend as K

from sklearn.metrics import mean_squared_error
from sklearn import preprocessing
from sklearn.metrics import *

import pickle
import gc

import random

random.seed(123)

# %% [markdown]
# <a name="1b"></a>
# ### Input Data Set

# %%
data_dir = "./data/"

print('Using 16-day sequence data set')
sequence_length = 16        # Number of days in sequence to train
wsize = 16
train_fname = data_dir + 'Lab3-AE-train-16day-8step.pkl'
test_fname = data_dir + 'Lab3-AE-test-16day-8step.pkl'
# Out:
# Using 16-day sequence data set

# %% [markdown]
# ### Data Set Information

# %% [markdown]
# As we experienced in the previous exercises, preparing large data sets can take some time.  So, for this exercise, we have created larger training and validation datasets which we will use for our training and testing.
#
# The datasets consists of 50000 sequences.  Each sequence is for an individual drive and tracks the SMART data features over 7 continuous days.  Since we will be training an Autoencoder to identify sequences for normal hard drive operation, we have not include any sequences that ended in drive failures.
#
# When we created these sequences, we assigned them a sequence id (field: "ae_seq_id") and a day number in the sequence (field: "ae_seq_data_id" which goes from 0-15).

# %% [markdown]
# ### Reading Training and Validation Datasets

# %%
# Reading larger training and test data set with only ST4000DM000 data
df = pd.read_pickle(train_fname)
print('Train Original shape:', df.shape)
# Out:
# Train Original shape: (74000, 46)

# %% [markdown]
# Let's take a look at our data set.  We'll print out the first 2 sequences.  You'll see the sequence id fields we discussed above.

# %%
df.head(2*sequence_length)
# Out:
#         ae_seq_id  ae_seq_data_id       date serial_number        model  \
# 195468        0.0             0.0 2017-07-28      Z300HM1N  ST4000DM000
# 195469        0.0             1.0 2017-07-29      Z300HM1N  ST4000DM000
# 195470        0.0             2.0 2017-07-30      Z300HM1N  ST4000DM000
# 195471        0.0             3.0 2017-07-31      Z300HM1N  ST4000DM000
# 195472        0.0             4.0 2017-08-01      Z300HM1N  ST4000DM000
# 195473        0.0             5.0 2017-08-02      Z300HM1N  ST4000DM000
# 195474        0.0             6.0 2017-08-03      Z300HM1N  ST4000DM000
# 195475        0.0             7.0 2017-08-04      Z300HM1N  ST4000DM000
# 195476        0.0             8.0 2017-08-05      Z300HM1N  ST4000DM000
# 195477        0.0             9.0 2017-08-06      Z300HM1N  ST4000DM000
# 195478        0.0            10.0 2017-08-07      Z300HM1N  ST4000DM000
# 195479        0.0            11.0 2017-08-08      Z300HM1N  ST4000DM000
# 195480        0.0            12.0 2017-08-09      Z300HM1N  ST4000DM000
# 200479                  97.0                  76.0                  79.0
# 200480                  97.0                  77.0                  78.0
# 200481                  97.0                  77.0                  78.0
#
#         smart_194_normalized  smart_197_normalized  smart_198_normalized  \
# 195468                  25.0                 100.0                 100.0
# 195469                  24.0                 100.0                 100.0
# 195470                  25.0                 100.0                 100.0
# 195471                  25.0                 100.0                 100.0
# 195472                  25.0                 100.0                 100.0
# 195473                  25.0                 100.0                 100.0
# 195474                  25.0                 100.0                 100.0
# 195475                  25.0                 100.0                 100.0
# 195476                  25.0                 100.0                 100.0
# 195477                  25.0                 100.0                 100.0
# 195478                  25.0                 100.0                 100.0
# 195479                  25.0                 100.0                 100.0
# 195480                  25.0                 100.0                 100.0
# 195481                  24.0                 100.0                 100.0
# 195482                  24.0                 100.0                 100.0
# 195483                  25.0                 100.0                 100.0
# 200466                  25.0                 100.0                 100.0
# 200467                  25.0                 100.0                 100.0
# 200468                  26.0                 100.0                 100.0
# 200469                  26.0                 100.0                 100.0
# 200470                  25.0                 100.0                 100.0
# 200471                  26.0                 100.0                 100.0
# 200472                  25.0                 100.0                 100.0
# 200473                  25.0                 100.0                 100.0
# 200474                  25.0                 100.0                 100.0
# 200475                  25.0                 100.0                 100.0
# 200476                  25.0                 100.0                 100.0
# 200477                  25.0                 100.0                 100.0
# 200478                  24.0                 100.0                 100.0
# 200479                  24.0                 100.0                 100.0
# 200480                  23.0                 100.0                 100.0
# 200481                  23.0                 100.0                 100.0
#
#         smart_199_normalized
# 195468                 200.0
# 195469                 200.0
# 195470                 200.0
# 195471                 200.0
# 195472                 200.0
# 195473                 200.0
# 195474                 200.0
# 195475                 200.0
# 195476                 200.0
# 195477                 200.0
# 195478                 200.0
# 195479                 200.0
# 195480                 200.0
# 195481                 200.0
# 195482                 200.0
# 195483                 200.0
# 200466                 200.0
# 200467                 200.0
# 200468                 200.0
# 200469                 200.0
# 200470                 200.0
# 200471                 200.0
# 200472                 200.0
# 200473                 200.0
# 200474                 200.0
# 200475                 200.0
# 200476                 200.0
# 200477                 200.0
# 200478                 200.0
# 200479                 200.0
# 200480                 200.0
# 200481                 200.0
#
# [32 rows x 46 columns]

# %% [markdown]
# ### Data preparation Routines

# %% [markdown]
# To work with the data, we are going to build a more structured set of functions that are going to help us with data curation. As stated in the previous lab, the dataset contains duplicated columns with "normalized" data. Our first function, `remove_normalized`, is aimed to remove those.

# %%
# Remove the "normalized" columns which are simply nomralized copies of the "raw" column

def remove_normalized(df):
    cols = [c for c in df.columns if (c.lower().find("normalized")==-1)]
    df=df[cols]
    return df

# %% [markdown]
# <a name="e1"></a>
#
# ### Exercise 1: Retrieve the output labels
#
# We would like to get the failure column in NumPy format. Please complete the following function to perform return the appropriate labels:

# %%
def get_Labels(df):
    # return the proper column in NumPy format
    y_labels = df['failure'].values
    return y_labels

# %% [markdown]
# ### Sort data based on `ae_seq_id` and `ae_seq_data_id` columns
#
# Prior to training, we need to ensure that all the data is properly sorted so that sequences are presented in the correct order.  Typically, we would sort the data by unique id and date/time.  When we created the data set for this exercise, we added two fields:
# <ul>
#     <li>ae_seq_id: Id number of unique sequence</li>
#     <li>ae_seq_data_id: Day number of record in sequence (day 0 - day (sequence_length-1))</li>
# </ul>

# %%
# Sort data frame to ensure proper order

def sort_dataframe(df):
    print("Sorting the data frame based on pre-created sequence id and sequence day id")
    df['date'] = pd.to_datetime(df['date'])
    
    #sort dataframe by 'ae_seq_id' and 'ae_seq_data_id'
    df = df.sort_values(by=['ae_seq_id', 'ae_seq_data_id'], axis=0, ascending=True)
    df = df.reset_index(drop=True)
    return df

# %% [markdown]
# Next we have created some "helper" functions to:
# <ul>
#     <li>Remove columns that possess no useful information for training</li>
#     <li>Normalize the columns</li>
# </ul>

# %%
# Remove columns unnecessary for training

def remove_columns(df, drop_columns_list = ['date','serial_number',
                                               'model', 
                                               'failure', 
                                               'capacity_bytes']):
    print("removing unnecessary columns")
    df = df.drop(columns=drop_columns_list)
    df = df.reset_index(drop=True)
    return df

# %%
# This routine removes the normalized features and removes unnecessary columns

def clean_dataframe(df,column_list=None):
        
    #sort the dataframe
    df = sort_dataframe(df)

    #remove normalized columns
    df = remove_normalized(df)

    #remove other unnecessary columns
    if column_list is not None:
        df = remove_columns(df, column_list)
    
    return df

# This routine scales values for training and reshapes data as appropriate for LSTM or CONV1D training

def normalize_df(df, ae_type=None,scaler=None):
    
    print("Normalizing input for "+ae_type)
    #normalize data with max/min values 
    df.fillna(0, inplace=True)
    x = df.values
    x = x.astype(np.float64)
    if scaler is None:
        scaler = preprocessing.StandardScaler().fit(x)
    x = scaler.transform(x)
    
    #reshape to obtain appropriate input for autoencoder
    if ae_type == "lstm": 
        x = x.reshape(int(x.shape[0]/sequence_length), sequence_length, x.shape[1])
    elif ae_type == "conv1d": 
        tshape = x.shape
        print(tshape, "dropping ", tshape[0]-int(tshape[0]/w_size)*w_size, end = " : reshaping to ")       
        x = x[:int(tshape[0]/w_size)*w_size,:].reshape(int(tshape[0]/w_size), w_size, tshape[1])

    print(x.shape)
    
    return x, scaler

# %% [markdown]
# We are going to load both training and test sets below, starting with the training set. Note that unlike the LSTM models, here we do not require the `failure` columns. The class labels are not what we learn, rather we learn the training data pattern. In that sense, autoencoders are unsupervised models.

# %%
print("processing the train set")

df = clean_dataframe(df,['ae_seq_id', 
                            'ae_seq_data_id', 
                            'date','serial_number',
                            'model', 
                            'failure', 
                           'capacity_bytes'])

x_train, scaler = normalize_df(df,"lstm")
# Out:
# processing the train set
# Sorting the data frame based on pre-created sequence id and sequence day id
# removing unnecessary columns
# Normalizing input for lstm
# (4625, 16, 21)

# %% [markdown]
# Let's take a look at a few samples of the data.

# %%
df.head(2*sequence_length)
# Out:
#     smart_1_raw  smart_4_raw  smart_5_raw  smart_7_raw  smart_9_raw
# 23            0.0            0.0            0.0        33487.0   3.084194e+10
# 24            0.0            0.0            0.0        33506.0   3.084206e+10
# 25            0.0            0.0            0.0        33525.0   3.084218e+10
# 26            0.0            0.0            0.0        33545.0   3.084230e+10
# 27            0.0            0.0            0.0        33564.0   3.084241e+10
# 28            0.0            0.0            0.0        33584.0   3.084253e+10
# 29            0.0            0.0            0.0        33603.0   3.084265e+10
# 30            0.0            0.0            0.0        33623.0   3.084277e+10
# 31            0.0            0.0            0.0        33642.0   3.084288e+10
#
#     smart_242_raw
# 0    1.425277e+11
# 1    1.425649e+11
# 2    1.426023e+11
# 3    1.426377e+11
# 4    1.426726e+11
# 5    1.427067e+11
# 6    1.427406e+11
# 7    1.427768e+11
# 8    1.428109e+11
# 9    1.428451e+11
# 10   1.428825e+11
# 11   1.429180e+11
# 12   1.429477e+11
# 13   1.429751e+11
# 14   1.430094e+11
# 15   1.430484e+11
# 16   1.919088e+11
# 17   1.919419e+11
# 18   1.919757e+11
# 19   1.920092e+11
# 20   1.920439e+11
# 21   1.920758e+11
# 22   1.921093e+11
# 23   1.921437e+11
# 24   1.921758e+11
# 25   1.922090e+11
# 26   1.922431e+11
# 27   1.922767e+11
# 28   1.923092e+11
# 29   1.923429e+11
# 30   1.923776e+11
# 31   1.924095e+11
#
# [32 rows x 21 columns]

# %% [markdown]
# Next, we are going to load the test set. Unlike, the train set, we require the `failure` column for the test set to evaluate the model accuracy at the end. Again, you can see that we are using the processed dataset from the previous lab for our test purposes.

# %%
df_test = pd.read_pickle(test_fname)
y_labels = get_Labels(df_test)

df_test = clean_dataframe(df_test, ['ae_seq_id', 'ae_seq_data_id', 'date','serial_number','model', 
                            'failure', 
                            'capacity_bytes'])

x_test, _ = normalize_df(df_test,'lstm',scaler=scaler)
# Out:
# Sorting the data frame based on pre-created sequence id and sequence day id
# removing unnecessary columns
# Normalizing input for lstm
# (834, 16, 21)

# %%
df_test.head(2*sequence_length)
# Out:
#     smart_1_raw  smart_4_raw  smart_5_raw  smart_7_raw  smart_9_raw  \
# 0    20931656.0          5.0          0.0  445083804.0      10497.0
# 1   172359472.0          5.0          0.0  445791739.0      10521.0
# 2    21705248.0          5.0          0.0  447586660.0      10545.0
# 3   129069792.0          5.0          0.0  448820783.0      10568.0
# 4    68452888.0          5.0          0.0  449512275.0      10593.0
# 5    59189440.0          5.0          0.0  449985857.0      10617.0
# 6   117643832.0          5.0          0.0  451076087.0      10641.0
# 7   210523216.0          5.0          0.0  451546733.0      10665.0
# 8     2369744.0          5.0          0.0  451908456.0      10689.0
# 9   130718904.0          5.0          0.0  452575870.0      10713.0
# 10  118628456.0          5.0          0.0  453641142.0      10737.0
# 11  182296152.0          5.0          0.0  454176955.0      10761.0
# 12   47644936.0          5.0          0.0  455687902.0      10785.0
# 13  209559408.0          5.0          0.0  456866368.0      10809.0
# 14   52369144.0          5.0          0.0  457597063.0      10833.0
# 15  179911504.0          5.0          0.0  458086103.0      10857.0
# 16  170489672.0          1.0          0.0  544653734.0      13739.0
# 17  218930264.0          1.0          0.0  545302736.0      13763.0
# 5    8.878416e+09
# 6    8.901264e+09
# 7    8.910142e+09
# 8    8.916714e+09
# 9    8.928378e+09
# 10   8.952648e+09
# 11   8.961123e+09
# 12   8.984780e+09
# 13   9.006662e+09
# 14   9.017427e+09
# 15   9.024461e+09
# 16   2.475205e+10
# 17   2.477526e+10
# 18   2.481269e+10
# 19   2.483501e+10
# 20   2.487543e+10
# 21   2.491775e+10
# 22   2.493543e+10
# 23   2.495545e+10
# 24   2.497250e+10
# 25   2.500865e+10
# 26   2.502570e+10
# 27   2.506768e+10
# 28   2.508617e+10
# 29   2.510276e+10
# 30   2.512448e+10
# 31   2.514321e+10
#
# [32 rows x 21 columns]

# %% [markdown]
# <a name="e2"></a>
# ### Exercise 2: Filtering the labels
#
# As for class labels, there is one extra filtering step. Take some time and try to figure the purpose behind the following command:

# %%
y_labels_seq = y_labels[sequence_length-1::sequence_length]

# %% [markdown]
# To label a particular sequence as normal or failed, we will use the 'failure' column from the last day of the sequence.  The above code finds the last day failure label to label the entire sequence.

# %% [markdown]
# # Part 1 - LSTM based autoencoder or seq2seq model

# %% [markdown]
# <a name="2"></a>
# ## Defining the LSTM Autoencoder Model

# %% [markdown]
# In this section, we are going to define two autoencoder models. The first model uses LSTMs as autoencoders. In this model, we create the autoencoder for time sequences using LSTM encoder-decoder models.
#
# An LSTM unit could be thought of an encoder unit where the input data are represented as a vector of a hidden states. We use this concept to encode the input into 1024 __bottleneck__ vectors. Afterwards we use another set of two LSTM units to reconstruct the original series.
#
# For the second model, we use a convolutional autoencoder. In this model, in order to encode the information, we use down-sampling (MaxPooling1D) and up-sampling (UpSampling1D) methods.

# %%
# Model #1 - Wide LSTM-based Encoder-Decoder
data_shape = x_train.shape[1:]   
    
## Some parameters to change
dp_lvl = 0.2
lstm_width = 128

inputs = Input(shape=(data_shape))
encoded = LSTM(lstm_width, dropout = dp_lvl, recurrent_dropout = dp_lvl, return_sequences =  False, activation='relu')(inputs)
decoded = RepeatVector(data_shape[0])(encoded)
decoded = LSTM(lstm_width, return_sequences=True, activation='relu')(decoded)
decoded = LSTM(data_shape[1], activation='tanh', return_sequences=True)(decoded)

# Build entire model
autoencoder = Model(inputs, decoded)

# Parameters to control learning rate
learning_rate = 0.001

optimizer = Adam(lr=learning_rate)
autoencoder.compile(optimizer=optimizer, loss='mae')
    
print(autoencoder.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 16, 21)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               76800
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 16, 128)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 16, 128)           131584
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 16, 21)            12600
# =================================================================
# Total params: 220,984
# Trainable params: 220,984
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# We setup callback routines to two callback routines
# <ul>
#     <li>ModelCheckpoint - stores a copy of our model weights for our best training epoch.  This can be used for later deployments.</li>
#     <li>EarlyStopping - stops the training early if the model is no longer improving.</li>
# </ul>

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# checkpoint
checkpoint = ModelCheckpoint(data_dir+"best_model_ae-lstm.h5", monitor='val_loss', 
                             verbose=1, save_best_only=True, mode='min')
es = EarlyStopping(patience=20, verbose=1)

callbacks_list = [es, checkpoint]

# %% [markdown]
# <a name="3"></a>
# ## Training the LSTM model
# Now that we've created our model, we'll go ahead and train it.  Then we'll evaluate the performance.

# %%
# train the model

# number of training epochs - feel free to change
#
# Time: 60 epochs ~= 3 minutes for LSTM

epochs_num = 60
history = autoencoder.fit(x_train, x_train, batch_size=128, epochs=epochs_num, validation_split=0.1, verbose=1, callbacks=callbacks_list)
# Out:
# Train on 4162 samples, validate on 463 samples
# Epoch 1/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.3818
# Epoch 00001: val_loss improved from inf to 0.30357, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 6s 1ms/sample - loss: 0.3796 - val_loss: 0.3036
# Epoch 2/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2991
# Epoch 00002: val_loss improved from 0.30357 to 0.27338, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 199us/sample - loss: 0.2989 - val_loss: 0.2734
# Epoch 3/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2724
# Epoch 00003: val_loss improved from 0.27338 to 0.25284, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 198us/sample - loss: 0.2726 - val_loss: 0.2528
# Epoch 4/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2585
# Epoch 00004: val_loss improved from 0.25284 to 0.23612, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 199us/sample - loss: 0.2584 - val_loss: 0.2361
# Epoch 5/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2442
# Epoch 00005: val_loss improved from 0.23612 to 0.22533, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 199us/sample - loss: 0.2441 - val_loss: 0.2253
# Epoch 6/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2363
# Epoch 00006: val_loss improved from 0.22533 to 0.21551, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 198us/sample - loss: 0.2361 - val_loss: 0.2155
# Epoch 7/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2277
# Epoch 00007: val_loss improved from 0.21551 to 0.21200, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 199us/sample - loss: 0.2276 - val_loss: 0.2120
# Epoch 8/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2258
# Epoch 00008: val_loss improved from 0.21200 to 0.20647, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 197us/sample - loss: 0.2250 - val_loss: 0.2065
# Epoch 9/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2226
# Epoch 00009: val_loss improved from 0.20647 to 0.20258, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 199us/sample - loss: 0.2217 - val_loss: 0.2026
# Epoch 10/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2178
# Epoch 00010: val_loss improved from 0.20258 to 0.19900, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 197us/sample - loss: 0.2177 - val_loss: 0.1990
# Epoch 11/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2174
# Epoch 00011: val_loss improved from 0.19900 to 0.19634, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 197us/sample - loss: 0.2161 - val_loss: 0.1963
# Epoch 12/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2113
# Epoch 00012: val_loss improved from 0.19634 to 0.19347, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 198us/sample - loss: 0.2132 - val_loss: 0.1935
# Epoch 13/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2092
# Epoch 00013: val_loss improved from 0.19347 to 0.19269, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 196us/sample - loss: 0.2095 - val_loss: 0.1927
# Epoch 14/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2088
# Epoch 00014: val_loss improved from 0.19269 to 0.19122, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 196us/sample - loss: 0.2086 - val_loss: 0.1912
# Epoch 15/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2062
# Epoch 00015: val_loss improved from 0.19122 to 0.18864, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 194us/sample - loss: 0.2064 - val_loss: 0.1886
# Epoch 16/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2061
# Epoch 00016: val_loss improved from 0.18864 to 0.18535, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 193us/sample - loss: 0.2055 - val_loss: 0.1854
# Epoch 17/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2033
# Epoch 00017: val_loss did not improve from 0.18535
# 4162/4162 [==============================] - 1s 173us/sample - loss: 0.2041 - val_loss: 0.1858
# Epoch 18/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2058
# Epoch 00018: val_loss did not improve from 0.18535
# 4162/4162 [==============================] - 1s 174us/sample - loss: 0.2058 - val_loss: 0.1861
# Epoch 19/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2029
# Epoch 00019: val_loss improved from 0.18535 to 0.18308, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 192us/sample - loss: 0.2030 - val_loss: 0.1831
# Epoch 20/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2014
# Epoch 00020: val_loss improved from 0.18308 to 0.18129, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 195us/sample - loss: 0.2010 - val_loss: 0.1813
# Epoch 21/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.1994
# Epoch 00021: val_loss improved from 0.18129 to 0.17950, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 194us/sample - loss: 0.1990 - val_loss: 0.1795
# Epoch 22/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.1970
# Epoch 00022: val_loss did not improve from 0.17950
# 4162/4162 [==============================] - 1s 174us/sample - loss: 0.1985 - val_loss: 0.1805
# Epoch 23/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.1965
# Epoch 00023: val_loss improved from 0.17950 to 0.17886, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 194us/sample - loss: 0.1983 - val_loss: 0.1789
# Epoch 24/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.1973
# Epoch 00024: val_loss improved from 0.17886 to 0.17883, saving model to ./data/best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 192us/sample - loss: 0.1977 - val_loss: 0.1788
# Epoch 25/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.1987
# Epoch 00025: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 173us/sample - loss: 0.1982 - val_loss: 0.1789
# Epoch 26/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2042
# Epoch 00026: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 173us/sample - loss: 0.2049 - val_loss: 0.1927
# Epoch 27/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2187
# Epoch 00027: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 174us/sample - loss: 0.2193 - val_loss: 0.2200
# Epoch 28/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2662
# Epoch 00028: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 174us/sample - loss: 0.2671 - val_loss: 0.2632
# Epoch 29/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2752
# Epoch 00029: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 173us/sample - loss: 0.2748 - val_loss: 0.2554
# Epoch 30/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2603
# Epoch 00030: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 174us/sample - loss: 0.2603 - val_loss: 0.2391
# Epoch 31/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2460
# Epoch 00031: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 175us/sample - loss: 0.2465 - val_loss: 0.2228
# Epoch 32/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2299
# Epoch 00032: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 173us/sample - loss: 0.2315 - val_loss: 0.2047
# Epoch 33/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2185
# Epoch 00033: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 173us/sample - loss: 0.2207 - val_loss: 0.1957
# Epoch 34/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2158
# Epoch 00034: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 174us/sample - loss: 0.2149 - val_loss: 0.1922
# Epoch 35/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2109
# Epoch 00035: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 173us/sample - loss: 0.2111 - val_loss: 0.1846
# Epoch 36/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2084
# Epoch 00036: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 174us/sample - loss: 0.2082 - val_loss: 0.1834
# Epoch 37/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2079
# Epoch 00037: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 173us/sample - loss: 0.2070 - val_loss: 0.1818
# Epoch 38/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2056
# Epoch 00038: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 175us/sample - loss: 0.2050 - val_loss: 0.1804
# Epoch 39/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2041
# Epoch 00039: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 175us/sample - loss: 0.2043 - val_loss: 0.1792
# Epoch 40/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2036
# Epoch 00040: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 174us/sample - loss: 0.2035 - val_loss: 0.1789
# Epoch 41/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2029
# Epoch 00041: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 173us/sample - loss: 0.2034 - val_loss: 0.1808
# Epoch 42/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2044
# Epoch 00042: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 175us/sample - loss: 0.2046 - val_loss: 0.1825
# Epoch 43/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2071
# Epoch 00043: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 174us/sample - loss: 0.2073 - val_loss: 0.1828
# Epoch 44/60
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2048
# Epoch 00044: val_loss did not improve from 0.17883
# 4162/4162 [==============================] - 1s 173us/sample - loss: 0.2056 - val_loss: 0.1811
# Epoch 00044: early stopping

# %% [markdown]
# Let's look at the loss function to see how accurate our training was.

# %%
# load weights from best model
print(data_dir+"best_model_ae-lstm.h5")
autoencoder.load_weights(data_dir+"best_model_ae-lstm.h5")
# Out:
# ./data/best_model_ae-lstm.h5

# %%
# show plot accuracy changes during training

plt.plot(history.history['loss'],'g')
plt.plot(history.history['val_loss'],'r')
plt.title('LSTM Loss across epochs')
plt.ylabel('Loss')
plt.xlabel('# epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %% [markdown]
# The model is starting to get trained, but at this point, the accuracy may not be that great.  In the real world, we train on even larger data sets for longer periods of time until the accurracy met our business requirements.  We also review the model and can increase it's complexity.

# %% [markdown]
# Let's go ahead and use our model to make predictions on the test data.  Remember, this is a reconstruction model, so the predictions, ideally, should look similar to the original data for normal disks.

# %%
# Use model to predict on test data set
y_pred = autoencoder.predict(x_test)

# %% [markdown]
# The next cell will plot a comparison of the original data to the predicted data for a random record. It compares the features for the first day in the sequence. Run it a few times to see how well your model came out.

# %%
# create horizontal positions for scatter plot
x_pos = np.arange(x_test.shape[2])

# select random record
rec_num = random.randint(0, y_pred.shape[0])

# plot predicted points
plt.scatter(x_pos, x_test[rec_num,0,:], c="#ff0000")
plt.scatter(x_pos, y_pred[rec_num,0,:], c="#0000ff")

# label graph
plt.xlabel("Feature")
plt.ylabel("Value")
plt.xticks(range(x_test.shape[2]))
plt.title("Compare original to reconstruction for day 0 of seq num " + str(rec_num))

if y_labels_seq[rec_num] == 0:
    print("This record is from a normal disk.")
else:
    print("This record is from an anomalous disk.")
# Out:
# This record is from an anomalous disk.

# %% [markdown]
# You'll see that once you have a trained model, you need to determine a "threshold" of difference in detecting an anomaly. In our case, we know the number of normal disks and the number of anomalous disks. We'll calculate the MSE for each reconstruction and set our initial threshold based on that. This should be a good point to start the threshold at. In real world usage, you'll adjust the model and threshold to obtain accuracy to meet your business needs. In our case we'd like the recall to be as high as possible to identify as many failing disks as possible.

# %%
# Calcuate MSE for all sequences and predictions
import statistics

# determine median mse to split data into normal vs anomaly
pred_mse = []  # calculated mse for test data
pred_res = []  # result: 0 normal, 1 anomaly

for i in range(len(x_test)):
    pred_mse.append(mean_squared_error(y_pred[i,:,:], x_test[i,:,:]))

# Find number of disks that we know are normal and use that value as splitting point for data
num_normal_disks = list(y_labels_seq).count(0)

sort_mse = pred_mse.copy()
sort_mse.sort()
suggested_threshold = sort_mse[num_normal_disks]
print("Suggested Threshold:", suggested_threshold)
# Out:
# Suggested Threshold: 0.15566227473163186

# %%
# Routine to specify whether or not a sequence is anomalous

# specify override threshold or leave 0 to use suggested threshold
override_threshold = 0

if override_threshold == 0:
    threshold = suggested_threshold
else:
    threshold = override_threshold

for mse in pred_mse:
    if (mse <= threshold):
        pred_res.append(0)
    else:
        pred_res.append(1)
        
print("Used threshold:", threshold)
print("Resulting in the following classification of predicted data:")
print("- Normal Disks:   ", pred_res.count(0))
print("- Anomalous Disks:", pred_res.count(1))
# Out:
# Used threshold: 0.15566227473163186
# Resulting in the following classification of predicted data:
# - Normal Disks:    601
# - Anomalous Disks: 233

# %% [markdown]
# <a name="3b"></a>
# ## Training the 1D Convolutional model
# Now that we've tested our LSTM model, let's create and train a 1D-Convolutional model.

# %%
checkpoint2 = ModelCheckpoint(data_dir+"best_model_ae-conv1d.h5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')
es2 = EarlyStopping(patience=20, verbose=1)

callbacks_list2 = [es2, checkpoint2]

# %% [markdown]
# Let's build out a 1D Convolution Model:

# %%
# Traditional Conv1D model

# Model parameter settings
sample_size = x_train.shape[1]
num_signals = x_train.shape[2]
dropout_rate = 0.2
outside_filters = 160
inside_filters = 80
ksize=6

# TTraditional 1D-Convolution Autoencoder

input_data = Input(shape=(sample_size, num_signals))
# --- Encode ---
encoded = Conv1D(filters=outside_filters, kernel_size=ksize, activation="relu", padding="same")(input_data)
encoded = MaxPooling1D(pool_size=2)(encoded)
encoded = Dropout(rate=dropout_rate)(encoded)
encoded = Conv1D(filters=inside_filters, kernel_size=ksize, activation="relu", padding="same")(encoded)
encoded = MaxPooling1D(pool_size=2)(encoded)
encoded = Dropout(rate=dropout_rate)(encoded)
# --- Encodings ---
encoded = Conv1D(filters=4, kernel_size=ksize, activation="relu", padding="same")(encoded)
encoded = Dropout(rate=dropout_rate)(encoded)
# --- Decode ---
decoded = UpSampling1D(size=2)(encoded)
decoded = Conv1D(filters=inside_filters, kernel_size=ksize, activation="relu", padding="same")(decoded)
decoded = Dropout(rate=dropout_rate)(decoded)
decoded = UpSampling1D(size=2)(decoded)
decoded = Conv1D(filters=outside_filters, kernel_size=ksize, activation="relu", padding="same")(decoded)
decoded = Dropout(rate=dropout_rate)(decoded)
# --- Output ---
output_layer = Conv1D(filters=num_signals, kernel_size=1, activation="linear", padding="same")(decoded)
autoencoder2 = Model(input_data, output_layer)
lr = 1e-3 # learning rate
autoencoder2.compile(optimizer = "adam", loss = "mse", metrics = ["accuracy"])
autoencoder2.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 16, 21)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 16, 160)           20320
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 8, 160)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 160)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 8, 80)             76880
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 4, 80)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 80)             0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 4, 4)              1924
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4)              0
# _________________________________________________________________
# up_sampling1d (UpSampling1D) (None, 8, 4)              0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 8, 80)             2000
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 80)             0
# _________________________________________________________________
# up_sampling1d_1 (UpSampling1 (None, 16, 80)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 16, 160)           76960
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 160)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 16, 21)            3381
# =================================================================
# Total params: 181,465
# Trainable params: 181,465
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the model

# number of training epochs - feel free to change
#
#       100 epochs ~= 3 minutes for Conv 1D

epochs_num = 100
history2 = autoencoder2.fit(x_train, x_train, batch_size=128, epochs=epochs_num, validation_split=0.1, verbose=1, callbacks=callbacks_list2)
# Out:
# Train on 4162 samples, validate on 463 samples
# Epoch 1/100
# 3328/4162 [======================>.......] - ETA: 0s - loss: 0.9072 - accuracy: 0.2404
# Epoch 00001: val_loss improved from inf to 0.50471, saving model to ./data/best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 1s 335us/sample - loss: 0.8872 - accuracy: 0.2447 - val_loss: 0.5047 - val_accuracy: 0.2701
# Epoch 2/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.6621 - accuracy: 0.2668
# Epoch 00002: val_loss improved from 0.50471 to 0.43963, saving model to ./data/best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 70us/sample - loss: 0.7884 - accuracy: 0.2691 - val_loss: 0.4396 - val_accuracy: 0.2430
# Epoch 3/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.7593 - accuracy: 0.2860
# Epoch 00003: val_loss improved from 0.43963 to 0.41485, saving model to ./data/best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 58us/sample - loss: 0.7395 - accuracy: 0.2866 - val_loss: 0.4149 - val_accuracy: 0.3078
# Epoch 4/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.7108 - accuracy: 0.2924
# Epoch 00004: val_loss improved from 0.41485 to 0.37541, saving model to ./data/best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 59us/sample - loss: 0.6992 - accuracy: 0.2925 - val_loss: 0.3754 - val_accuracy: 0.3152
# Epoch 5/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.7015 - accuracy: 0.2917
# Epoch 00005: val_loss did not improve from 0.37541
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.6889 - accuracy: 0.2842 - val_loss: 0.3836 - val_accuracy: 0.2858
# Epoch 6/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.6711 - accuracy: 0.2501
# Epoch 00006: val_loss improved from 0.37541 to 0.34818, saving model to ./data/best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 58us/sample - loss: 0.6391 - accuracy: 0.2460 - val_loss: 0.3482 - val_accuracy: 0.2535
# Epoch 7/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.5572 - accuracy: 0.2257
# Epoch 00007: val_loss improved from 0.34818 to 0.31276, saving model to ./data/best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 58us/sample - loss: 0.6200 - accuracy: 0.2302 - val_loss: 0.3128 - val_accuracy: 0.2785
# Epoch 8/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0
100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.5024 - accuracy: 0.4896
# Epoch 00023: val_loss improved from 0.21356 to 0.21217, saving model to ./data/best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 59us/sample - loss: 0.4726 - accuracy: 0.4890 - val_loss: 0.2122 - val_accuracy: 0.4341
# Epoch 24/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3306 - accuracy: 0.5003
# Epoch 00024: val_loss improved from 0.21217 to 0.20432, saving model to ./data/best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 59us/sample - loss: 0.4528 - accuracy: 0.5016 - val_loss: 0.2043 - val_accuracy: 0.4906
# Epoch 25/100
# 3584/4162 [========================>.....] - ETA: 0s - loss: 0.5146 - accuracy: 0.4761
# Epoch 00025: val_loss did not improve from 0.20432
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.4810 - accuracy: 0.4753 - val_loss: 0.2268 - val_accuracy: 0.4843
# Epoch 26/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.5065 - accuracy: 0.4725
# Epoch 00026: val_loss did not improve from 0.20432
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.4699 - accuracy: 0.4705 - val_loss: 0.2045 - val_accuracy: 0.4241
# Epoch 27/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.4660 - accuracy: 0.4979
# Epoch 00027: val_loss improved from 0.20432 to 0.19155, saving model to ./data/best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 58us/sample - loss: 0.4489 - accuracy: 0.5011 - val_loss: 0.1916 - val_accuracy: 0.4897
# Epoch 28/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.4585 - accuracy: 0.5102
# Epoch 00028: val_loss improved from 0.19155 to 0.18925, saving model to ./data/best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 58us/sample - loss: 0.4530 - accuracy: 0.5092 - val_loss: 0.1892 - val_accuracy: 0.5386
# Epoch 29/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.4400 - accuracy: 0.5085
# Epoch 00029: val_loss did not improve from 0.18925
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.4121 - accuracy: 0.5052 - val_loss: 0.1965 - val_accuracy: 0.5175
# Epoch 30/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3708 - accuracy: 0.5356
# Epoch 00030: val_loss did not improve from 0.18925
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.3859 - accuracy: 0.5338 - val_loss: 0.1979 - val_accuracy: 0.5432
# Epoch 31/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.4754 - accuracy: 0.5087
# Epoch 00031: val_loss did not improve from 0.18925
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.4388 - accuracy: 0.5101 - val_loss: 0.2011 - val_accuracy: 0.5126
# Epoch 32/100
# 3584/4162 [========================>.....] - ETA: 0s - loss: 0.3822 - accuracy: 0.5308
# Epoch 00032: val_loss improved from 0.18925 to 0.17712, saving model to ./data/best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 61us/sample - loss: 0.3852 - accuracy: 0.5333 - val_loss: 0.1771 - val_accuracy: 0.6010
# Epoch 33/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.4147 - accuracy: 0.5279
# Epoch 00033: val_loss did not improve from 0.17712
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.4433 - accuracy: 0.5290 - val_loss: 0.2027 - val_accuracy: 0.5749
# Epoch 34/100
# 3712/4162 [=========================>....] - ETA: 0s - loss: 0.4212 - accuracy: 0.5140
# Epoch 00034: val_loss did not improve from 0.17712
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.4048 - accuracy: 0.5150 - val_loss: 0.2027 - val_accuracy: 0.5329
# Epoch 35/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3657 - accuracy: 0.5310
# Epoch 00035: val_loss did not improve from 0.17712
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.3866 - accuracy: 0.5360 - val_loss: 0.1922 - val_accuracy: 0.6118
# Epoch 36/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.4125 - accuracy: 0.5380
# Epoch 00036: val_loss did not improve from 0.17712
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.4015 - accuracy: 0.5352 - val_loss: 0.1836 - val_accuracy: 0.4776
# Epoch 37/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.4363 - accuracy: 0.5189
# Epoch 00037: val_loss did not improve from 0.17712
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.4094 - accuracy: 0.5195 - val_loss: 0.1878 - val_accuracy: 0.4966
# Epoch 38/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3617 - accuracy: 0.5349
# Epoch 00038: val_loss improved from 0.17712 to 0.17592, saving model to ./data/best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 58us/sample - loss: 0.3976 - accuracy: 0.5330 - val_loss: 0.1759 - val_accuracy: 0.5477
# Epoch 39/100
# 2688/4162 [==================>...........] - ETA: 0s - loss: 0.4416 - accuracy: 0.5367
# Epoch 00039: val_loss did not improve from 0.17592
# 4162/4162 [==============================] - 1s 294us/sample - loss: 0.4052 - accuracy: 0.5433 - val_loss: 0.1866 - val_accuracy: 0.5544
# Epoch 40/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3795 - accuracy: 0.5415
# Epoch 00040: val_loss did not improve from 0.17592
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.3648 - accuracy: 0.5454 - val_loss: 0.1812 - val_accuracy: 0.5506
# Epoch 41/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3974 - accuracy: 0.5285
# Epoch 00041: val_loss did not improve from 0.17592
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.3947 - accuracy: 0.5303 - val_loss: 0.2059 - val_accuracy: 0.4872
# Epoch 42/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.4802 - accuracy: 0.5249
# Epoch 00042: val_loss did not improve from 0.17592
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.4444 - accuracy: 0.5302 - val_loss: 0.2294 - val_accuracy: 0.4965
# Epoch 43/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.4610 - accuracy: 0.5241
# Epoch 00043: val_loss did not improve from 0.17592
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.4311 - accuracy: 0.5231 - val_loss: 0.1939 - val_accuracy: 0.5601
# Epoch 44/100
# 3712/4162 [=========================>....] - ETA: 0s - loss: 0.4045 - accuracy: 0.5552
# Epoch 00044: val_loss improved from 0.17592 to 0.17319, saving model to ./data/best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 57us/sample - loss: 0.3882 - accuracy: 0.5533 - val_loss: 0.1732 - val_accuracy: 0.5705
# Epoch 45/100
# 3712/4162 [=========================>....] - ETA: 0s - loss: 0.3606 - accuracy: 0.5593
# Epoch 00045: val_loss did not improve from 0.17319
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.3746 - accuracy: 0.5550 - val_loss: 0.1789 - val_accuracy: 0.5378
# Epoch 46/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3239 - accuracy: 0.5528
# Epoch 00046: val_loss did not improve from 0.17319
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.3666 - accuracy: 0.5465 - val_loss: 0.2070 - val_accuracy: 0.5202
# Epoch 47/100
# 3584/4162 [========================>.....] - ETA: 0s - loss: 0.3908 - accuracy: 0.5111
# Epoch 00047: val_loss did not improve from 0.17319
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.3735 - accuracy: 0.5166 - val_loss: 0.1955 - val_accuracy: 0.5269
# Epoch 48/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3602 - accuracy: 0.5487
# Epoch 00048: val_loss did not improve from 0.17319
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.3805 - accuracy: 0.5510 - val_loss: 0.1800 - val_accuracy: 0.5567
# Epoch 49/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3834 - accuracy: 0.5465
# Epoch 00049: val_loss did not improve from 0.17319
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.3647 - accuracy: 0.5429 - val_loss: 0.1896 - val_accuracy: 0.5776
# Epoch 50/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3840 - accuracy: 0.5586
# Epoch 00050: val_loss improved from 0.17319 to 0.16467, saving model to ./data/best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 57us/sample - loss: 0.3744 - accuracy: 0.5570 - val_loss: 0.1647 - val_accuracy: 0.5821
# Epoch 51/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3330 - accuracy: 0.5657
# Epoch 00051: val_loss did not improve from 0.16467
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.3620 - accuracy: 0.5650 - val_loss: 0.1663 - val_accuracy: 0.5940
# Epoch 52/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3310 - accuracy: 0.5813
# Epoch 00052: val_loss did not improve from 0.16467
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.3153 - accuracy: 0.5831 - val_loss: 0.1805 - val_accuracy: 0.5934
# Epoch 53/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3136 - accuracy: 0.5808
# Epoch 00053: val_loss improved from 0.16467 to 0.15717, saving model to ./data/best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 58us/sample - loss: 0.3208 - accuracy: 0.5751 - val_loss: 0.1572 - val_accuracy: 0.5448
# Epoch 54/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3412 - accuracy: 0.5727
# Epoch 00054: val_loss did not improve from 0.15717
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.3311 - accuracy: 0.5636 - val_loss: 0.2015 - val_accuracy: 0.4741
# Epoch 55/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.4017 - accuracy: 0.5426
# Epoch 00055: val_loss did not improve from 0.15717
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.4208 - accuracy: 0.5465 - val_loss: 0.1648 - val_accuracy: 0.5632
# Epoch 56/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0
100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3227 - accuracy: 0.5761
# Epoch 00076: val_loss did not improve from 0.14857
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.3627 - accuracy: 0.5753 - val_loss: 0.2012 - val_accuracy: 0.5674
# Epoch 77/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3348 - accuracy: 0.5589
# Epoch 00077: val_loss did not improve from 0.14857
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.3428 - accuracy: 0.5610 - val_loss: 0.1724 - val_accuracy: 0.5389
# Epoch 78/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3125 - accuracy: 0.5559
# Epoch 00078: val_loss did not improve from 0.14857
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.3420 - accuracy: 0.5572 - val_loss: 0.1863 - val_accuracy: 0.6011
# Epoch 79/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3514 - accuracy: 0.5669
# Epoch 00079: val_loss did not improve from 0.14857
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.3569 - accuracy: 0.5638 - val_loss: 0.1949 - val_accuracy: 0.5404
# Epoch 80/100
# 3584/4162 [========================>.....] - ETA: 0s - loss: 0.3562 - accuracy: 0.5631
# Epoch 00080: val_loss did not improve from 0.14857
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.3473 - accuracy: 0.5657 - val_loss: 0.1735 - val_accuracy: 0.5989
# Epoch 81/100
# 3584/4162 [========================>.....] - ETA: 0s - loss: 0.2990 - accuracy: 0.5598
# Epoch 00081: val_loss did not improve from 0.14857
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.2875 - accuracy: 0.5657 - val_loss: 0.1571 - val_accuracy: 0.6006
# Epoch 82/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.2765 - accuracy: 0.5832
# Epoch 00082: val_loss did not improve from 0.14857
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.2730 - accuracy: 0.5848 - val_loss: 0.1575 - val_accuracy: 0.6178
# Epoch 83/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.2832 - accuracy: 0.5916
# Epoch 00083: val_loss did not improve from 0.14857
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.2785 - accuracy: 0.5873 - val_loss: 0.1583 - val_accuracy: 0.6127
# Epoch 84/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.2432 - accuracy: 0.5886
# Epoch 00084: val_loss improved from 0.14857 to 0.14497, saving model to ./data/best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 58us/sample - loss: 0.2440 - accuracy: 0.5875 - val_loss: 0.1450 - val_accuracy: 0.5922
# Epoch 85/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.2484 - accuracy: 0.5833
# Epoch 00085: val_loss did not improve from 0.14497
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.3076 - accuracy: 0.5847 - val_loss: 0.1456 - val_accuracy: 0.6012
# Epoch 86/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.2831 - accuracy: 0.5813
# Epoch 00086: val_loss did not improve from 0.14497
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.2812 - accuracy: 0.5810 - val_loss: 0.1636 - val_accuracy: 0.5610
# Epoch 87/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3177 - accuracy: 0.5846
# Epoch 00087: val_loss did not improve from 0.14497
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.3190 - accuracy: 0.5829 - val_loss: 0.1575 - val_accuracy: 0.5827
# Epoch 88/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3402 - accuracy: 0.5918
# Epoch 00088: val_loss did not improve from 0.14497
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.3218 - accuracy: 0.5926 - val_loss: 0.1532 - val_accuracy: 0.6316
# Epoch 89/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.2838 - accuracy: 0.5909
# Epoch 00089: val_loss did not improve from 0.14497
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.3003 - accuracy: 0.5891 - val_loss: 0.1532 - val_accuracy: 0.5652
# Epoch 90/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.2888 - accuracy: 0.5802
# Epoch 00090: val_loss did not improve from 0.14497
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.2738 - accuracy: 0.5811 - val_loss: 0.1591 - val_accuracy: 0.5962
# Epoch 91/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.2412 - accuracy: 0.5894
# Epoch 00091: val_loss did not improve from 0.14497
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.2425 - accuracy: 0.5898 - val_loss: 0.1470 - val_accuracy: 0.5859
# Epoch 92/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.2890 - accuracy: 0.5888
# Epoch 00092: val_loss did not improve from 0.14497
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.2763 - accuracy: 0.5876 - val_loss: 0.1605 - val_accuracy: 0.6064
# Epoch 93/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.2909 - accuracy: 0.5897
# Epoch 00093: val_loss did not improve from 0.14497
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.2886 - accuracy: 0.5895 - val_loss: 0.1703 - val_accuracy: 0.6192
# Epoch 94/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.2499 - accuracy: 0.6015
# Epoch 00094: val_loss did not improve from 0.14497
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.2658 - accuracy: 0.5955 - val_loss: 0.1477 - val_accuracy: 0.5813
# Epoch 95/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.2914 - accuracy: 0.5801
# Epoch 00095: val_loss did not improve from 0.14497
# 4162/4162 [==============================] - 0s 37us/sample - loss: 0.2927 - accuracy: 0.5761 - val_loss: 0.1804 - val_accuracy: 0.5614
# Epoch 96/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.2679 - accuracy: 0.5972
# Epoch 00096: val_loss did not improve from 0.14497
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.2881 - accuracy: 0.5971 - val_loss: 0.1778 - val_accuracy: 0.6110
# Epoch 97/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.2962 - accuracy: 0.5687
# Epoch 00097: val_loss did not improve from 0.14497
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.2935 - accuracy: 0.5675 - val_loss: 0.1782 - val_accuracy: 0.5305
# Epoch 98/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.3053 - accuracy: 0.5941
# Epoch 00098: val_loss did not improve from 0.14497
# 4162/4162 [==============================] - 0s 36us/sample - loss: 0.2922 - accuracy: 0.5942 - val_loss: 0.1657 - val_accuracy: 0.5733
# Epoch 99/100
# 3584/4162 [========================>.....] - ETA: 0s - loss: 0.2968 - accuracy: 0.6052
# Epoch 00099: val_loss did not improve from 0.14497
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.2830 - accuracy: 0.6020 - val_loss: 0.1515 - val_accuracy: 0.5782
# Epoch 100/100
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.2522 - accuracy: 0.5979
# Epoch 00100: val_loss did not improve from 0.14497
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.2590 - accuracy: 0.5980 - val_loss: 0.1615 - val_accuracy: 0.6504

# %%
# load weights from best model
print(data_dir+"best_model_ae-conv1d.h5")
autoencoder2.load_weights(data_dir+"best_model_ae-conv1d.h5")
# Out:
# ./data/best_model_ae-conv1d.h5

# %%
# show plot accuracy changes during training

plt.plot(history2.history['loss'],'g')
plt.plot(history2.history['val_loss'],'r')
plt.title('1D-Conv Loss across epochs')
plt.ylabel('Loss')
plt.xlabel('# epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %% [markdown]
# Let's go ahead and use our model to make predictions on the test data. Remember, this is a reconstruction model, so the predictions, ideally, should look similar to the original data for normal disks.

# %%
# Use model to predict on test data set
y_pred2 = autoencoder2.predict(x_test)

# %% [markdown]
# The next cell will plot a comparison of the original data to the predicted data for a random record. It only shows compares the features for the first day in the sequence. Run it a few times to see how well your model came out.

# %%
# create horizontal positions for scatter plot
x_pos = np.arange(x_test.shape[2])

# select random record
rec_num = random.randint(0, y_pred.shape[0])

# plot predicted points
plt.scatter(x_pos, x_test[rec_num,0,:], c="#ff0000")
plt.scatter(x_pos, y_pred2[rec_num,0,:], c="#0000ff")

# label graph
plt.xlabel("Feature")
plt.ylabel("Value")
plt.xticks(range(x_test.shape[2]))
plt.title("Compare original to reconstruction for day 0 of seq num " + str(rec_num))

if y_labels_seq[rec_num] == 0:
    print("This record is from a normal disk.")
else:
    print("This record is from an anomalous disk.")
# Out:
# This record is from a normal disk.

# %% [markdown]
# Like before, we need to determine a "threshold" of difference in detecting an anomaly. We'll use the same technique on the new data to determine our threshold.

# %%
# Calcuate MSE for all sequences and predictions
import statistics

# determine median mse to split data into normal vs anomaly
pred_mse2 = []  # calculated mse for test data
pred_res2 = []  # result: 0 normal, 1 anomaly

for i in range(len(x_test)):
    pred_mse2.append(mean_squared_error(y_pred2[i,:,:], x_test[i,:,:]))

# Find number of disks that we know are normal and use that value as splitting point for data
num_normal_disks = list(y_labels_seq).count(0)

sort_mse2 = pred_mse2.copy()
sort_mse2.sort()
suggested_threshold2 = sort_mse2[num_normal_disks]
print("Suggested Threshold:", suggested_threshold2)
# Out:
# Suggested Threshold: 0.1777364960109314

# %%
# Routine to specify whether or not a sequence is anomalous

# specify override threshold or leave 0 to use suggested threshold
override_threshold2 = 0

if override_threshold2 == 0:
    threshold2 = suggested_threshold2
else:
    threshold2 = override_threshold2

for mse in pred_mse2:
    if (mse <= threshold2):
        pred_res2.append(0)
    else:
        pred_res2.append(1)
        
print("Used threshold:", threshold2)
print("Resulting in the following classification of predicted data:")
print("- Normal Disks:   ", pred_res2.count(0))
print("- Anomalous Disks:", pred_res2.count(1))
# Out:
# Used threshold: 0.1777364960109314
# Resulting in the following classification of predicted data:
# - Normal Disks:    601
# - Anomalous Disks: 233

# %% [markdown]
# ## ROC Curve
#
# The ROC curve plots the False Positive rate along the horizontal axis and the True Positive rate along the vertical axis. False Positive rate and True Positive rate will change based on the various threshold values.
#
# The threshold is high at the y-intercept, resulting in a 0% False Positive rate and a low True Positive rate. As the threshold decreases, the True Positive rate will increase but so will the False Positive rate.
#
# Perfect classification occurs if the distribution of anomalous disks and normal disks are completely separated. This would yield a point in the upper left corner of the ROC space, where the False Positive rate is 0% and the True Positive rate is 100%.
#
# https://en.wikipedia.org/wiki/Receiver_operating_characteristic
#
# Check the ROC curve of the LSTM model.

# %%
from sklearn.metrics import roc_curve, auc


def roc_auc_show(pred_y, y_label, figure_label_name='LSTM'):
    fpr, tpr, _ = roc_curve(y_label, pred_y)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    lw = 2
    plt.plot(fpr, tpr, color='darkorange',
             lw=lw, label=figure_label_name + ' ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

roc_auc_show(pred_mse, y_labels_seq)

# %% [markdown]
# Check the ROC curve of the 1D-Conv model.

# %%
roc_auc_show(pred_mse2, y_labels_seq, figure_label_name='CNN LSTM')

# %% [markdown]
# ### Performance comparison of LSTM and 1D-Conv models

# %% [markdown]
# Now that you've tested both LSTM and the 1D Convultional anomaly detectors, how do you think their accuracy and performance compared?

# %%
from sklearn.metrics import classification_report

y_test = []

for i in np.arange(0, len(y_labels), sequence_length):
    y_test.append(max(y_labels[i:i+sequence_length]))

print('For LSTM AE')
print(classification_report(y_test, pred_res))
print('For 1D Conv AE')
print(classification_report(y_test, pred_res2))
# Out:
# For LSTM AE
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81       600
#            1       0.51      0.50      0.51       234
#
#     accuracy                           0.72       834
#    macro avg       0.66      0.66      0.66       834
# weighted avg       0.72      0.72      0.72       834
#
# For 1D Conv AE
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81       600
#            1       0.51      0.50      0.51       234
#
#     accuracy                           0.72       834
#    macro avg       0.66      0.66      0.66       834
# weighted avg       0.72      0.72      0.72       834

# %% [markdown]
# ## STOP HERE -- END OF SESSION 3
# We will complete Exercise 3 as part of next session of DLI.

# %% [markdown]
# <a name="e4"></a>
# ### Exercise 3: Experimenting with Hyperparameters
#
# Now that you've worked your through the entire notebook, feel free to go back and adjust the models to see if you can improve accuracy.  You can add layers, increase filters, and change hyperparameters.  This is where the real art of Deep Learning happens...
#
# However, it is possible to take a systematic approach to hyperparameter optimization by sweeping the space of all parameter values and finding those which maximize some metric you're interested in.  We can then define a function to construct our model based on a given set of parameters, as well as define a scoring function which creates and trains the model and evaluates it's performance. There are many approaches to perform hyperparameter optimization using Deep Learning models. We will explore one concept called Bayesian Optimization which is a fairly common approach for this type of optimization.
#
# In this example, we'll continue with the LSTM model designed previously and set up the parameter search space to include adjusting the dropout rate and LSTM width along with a factor describing how much of the suggested threshold to use when classifying a defective disk.  In more complicated models, other hyperparameters such as the number of stacked LSTM layers or convolution kernel width could be included in the search space.  Just keep in mind that each new parameter will expand the search space and require more time to maximize.
#
# ![Bayesian Optimization](https://raw.githubusercontent.com/fmfn/BayesianOptimization/master/examples/bayesian_optimization.gif)

# %% [markdown]
# Import the python package for optimizing the architecture for the LSTM autoencoder

# %%
# !pip install bayesian-optimization
from bayes_opt import BayesianOptimization
# Out:
# Requirement already satisfied: bayesian-optimization in /opt/conda/envs/rapids/lib/python3.6/site-packages (1.2.0)
# Requirement already satisfied: numpy>=1.9.0 in /opt/conda/envs/rapids/lib/python3.6/site-packages (from bayesian-optimization) (1.18.5)
# Requirement already satisfied: scipy>=0.14.0 in /opt/conda/envs/rapids/lib/python3.6/site-packages (from bayesian-optimization) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.18.0 in /opt/conda/envs/rapids/lib/python3.6/site-packages (from bayesian-optimization) (0.23.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/envs/rapids/lib/python3.6/site-packages (from scikit-learn>=0.18.0->bayesian-optimization) (0.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/envs/rapids/lib/python3.6/site-packages (from scikit-learn>=0.18.0->bayesian-optimization) (2.1.0)

# %% [markdown]
# Now we can create a class **Hyperparameter** to create inputs for the optimization and provide a mapping between unscaled parameters required by optimizater and scaled parameters used in the method **lstm_autoencoder** defined below:

# %%
class Hyperparameter: 
    
    def __init__(self,inputs=None):
        
        _defaults = {"min": 0, "max": 1.0, "count": 11, "scale" : "linear", "type" : "float" }
        
        for key in sorted(_defaults.keys()): 
            try:
                _defaults[key] = inputs[key]
            except:
                pass
        
        if inputs is not None: 
            for key in sorted(_defaults.keys()):
                try:
                    eval("self.set_"+key)(_defaults[key])
                except:
                    print(key + "not defined for Hyperparameter " )
            self.update()
            
        print(self)
            
    def set_min(self,val=None):
        self.min = val 
        
    def set_max(self,val=None):
        self.max = val 
        
    def set_count(self,val=None):
        self.count = val 
        
    def set_step(self,val=None):
        self.step = val 
                     
    def set_type(self,val=None):
        self.type = val 

    def set_scale(self,val=None):
        self.scale = val 
        
    def update(self):
        if self.scale == "log":
             self.step = (np.log(self.max) - np.log(self.min))/(self.count-1)
        else:
             self.step = (self.max - self.min)/(self.count-1)
        if self.type == "int": 
            self.step = int(self.step)
        
    def from_unscaled(self,val=None): 
        if self.scale == "log":
            _tval =  np.exp(np.log(self.min) + self.step*val)
        else:
            _tval =  self.min + self.step*val
        
        if self.type == "int":
            _tval = int(_tval)
        
        return _tval 
    
    def to_unscaled(self,val=None): 
        if self.scale == "log":
            _tval =  (np.log(val) - np.log(self.min))/self.step
        else:
            _tval =  (val - self.min)/self.step
        
        if self.type == "int":
            _tval = int(_tval)
        
        return _tval 
    
    def __repr__(self):
        
        _cur_str = ' Hyperparameter (min: {}, max: {}, scale: {}, step: {}, count: {}, type: {})'.format(self.min,
                                         self.max,
                                         self.scale,
                                         self.step, 
                                         self.count, 
                                         self.type )
        return  _cur_str

# %% [markdown]
# Method to plot the training history of each architecture

# %%
def plot_history(history,result,lw,lr):
    plt.figure()
    plt.plot(history['loss'],'g')
    plt.plot(history['val_loss'],'r')

    plt.ylabel('Loss')
    plt.xlabel('# epoch')
    plt.legend(['train', 'test'], loc='lower right')
    plt.ylim([0.15,0.55])
    plt.title("LSTM Loss across epochs \n lstm width {:7d} learning rate {:7.4f} objective {:7.4f}" .format(lw,lr,result))

# %% [markdown]
# <br>
# Next define a function to train the model and return the accuracy:

# %%
# Model #1 - Wide LSTM-based Encoder-Decoder
data_shape = x_train.shape[1:]  

dp_lvl = 0.2

def lstm_autoencoder(data_shape, params_list):
    
    
    mod_params = {} 
    mod_params['lstm_width'] = lstm_width.from_unscaled(int(np.round(params_list[0])))
    mod_params['learning_rate'] = learning_rate.from_unscaled(params_list[1])
    mod_params['num_epochs'] = 20
    mod_params['batch_size'] = 128 
    
    inputs = Input(shape=(data_shape))
    encoded = LSTM(int(mod_params["lstm_width"]), dropout = dp_lvl, recurrent_dropout = dp_lvl, return_sequences =  False, activation='relu')(inputs)
    decoded = RepeatVector(data_shape[0])(encoded)
    decoded = LSTM(int(mod_params["lstm_width"]), return_sequences=True, activation='relu')(decoded)
    decoded = LSTM(data_shape[1], activation='tanh', return_sequences=True)(decoded)

    # Build entire model
    autoencoder = Model(inputs, decoded)
    
    filename = "case_%.3e_%d_best_model_ae-lstm.h5" %  \
                                 (mod_params["learning_rate"],mod_params["lstm_width"])
    if print_flag == 1:
        print(autoencoder.summary())
    return autoencoder, filename, mod_params

# %% [markdown]
# #### Utility methods for plotting and reporting resutls

# %%
def print_history(num_step, mod_params, loss, result, num_train, num_non_train, run_time):

    if num_step == 0: 
        print("\n| {:>9s} | {:>10s} | {:>13s} | {:>6s} | {:>9s} | {:>9s} | {:>13s} | {:>15s} | \n|".format("Iteration", "lstm width",
                                                                         "learning rate",
                                                                         "loss","objective", "trainable", "non trainable",
                                                                         "run time (mins)")+'-'*107+"|")
        
    print( "| {:>9d} | {:>10d} | {:>13.6f} | {:>6.4f} | {:>9.4f} | {:>9d} | {:>13d} | {:>15.4f} |".format( num_step + 1,
        mod_params['lstm_width'],mod_params['learning_rate'],loss, result, num_train, num_non_train, run_time))

# %%
def plot_model_loss(idx_list,header): 
    
    print(" "*20 + header)
    for idx in idx_list:
        cur_iter = iter_history[idx]
        iter_history[idx]["model"].summary()
        plot_history(cur_iter["history"],cur_iter['objective'],
                     cur_iter['params']["lstm_width"],cur_iter['params']["learning_rate"])

# %%
def plot_loss_map(results_list):
    results_list_shifted = [r - 0.9*min_res for r in results_list]
    plt.figure(figsize=(6,4))
    plt.scatter([c['params']['lstm_width'] for c in iter_history],
                [c['params']['learning_rate'] for c in iter_history],
                s=[r*500 for r in results_list_shifted],
                c=[r for r in results_list_shifted ])

    for i,c in enumerate(iter_history):
        plt.text(c['params']['lstm_width'], c['params']['learning_rate'], r'%d'%(i),fontsize = 14)
    plt.xlabel('lstm_width',fontsize=14)
    plt.ylabel('learning_rate',fontsize=14)
    plt.tick_params(labelsize=12)
    plt.yscale('log')

# %% [markdown]
# <br>
#
# ### Main method for building the autoencoder
# This method builds the autoencoder and trains using provided data using
# * method **lstm_autoencoder**
# * print history of training with the inputs to the architecture of the LSTM model

# %%
import statistics
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

print_flag = 0 
iter_history = []

def count_params(model, param_type = "train"): # Compute number of params in a model (the actual number of floats)
    if param_type == "train":
        return sum([np.prod(K.get_value(w).shape) for w in model.trainable_weights])
    else: 
        return sum([np.prod(K.get_value(w).shape) for w in model.non_trainable_weights])
        
def train_and_fit_AE(param1, param2):
    
    time_start = time.time()
    autoencoder, filename, params  = lstm_autoencoder(data_shape, [param1, param2])
   
    # checkpoint
    checkpoint = ModelCheckpoint(data_dir+filename, monitor='val_loss', 
                                 verbose=print_flag, save_best_only=True, mode='min')
    es = EarlyStopping(patience=15, verbose=print_flag)

    optimizer = Adam(lr=params['learning_rate'])
    autoencoder.compile(optimizer=optimizer, loss='mae')

    history = autoencoder.fit(x_train, x_train, batch_size=params['batch_size'], epochs=params['num_epochs'], 
                              validation_split=0.1, verbose=print_flag, callbacks=[es, checkpoint])
    loss = history.history["val_loss"][-1]
    if np.isnan(loss) : loss = 1e8
    result = np.exp(-20*loss**2) 

    print_history(len(iter_history), params, loss, result, 
                  count_params(autoencoder,"train"), 
                  count_params(autoencoder,"non_train"),
                  (time.time()-time_start)/60.0)
    iter_history.append({'objective':result, 'params': params, 'history':history.history, "model" : autoencoder})
    
    return result

# %% [markdown]
# Let's define the parameter space:

# %%
lstm_width = Hyperparameter({"min": 32, "max": 128, "count": 15, "type" : "int" })
learning_rate = Hyperparameter({"min": 0.0005, "max": 0.1, "count": 15, "scale" : "log"})

pbounds = {"param1"       : (0,lstm_width.count-1),
           "param2"    : (0,learning_rate.count-1)}
# Out:
#  Hyperparameter (min: 32, max: 128, scale: linear, step: 6, count: 15, type: int)
#  Hyperparameter (min: 0.0005, max: 0.1, scale: log, step: 0.37845124046771694, count: 15, type: float)

# %% [markdown]
# Let's run one test of our "train_and_fit" function to ensure it runs correctly.

# %%
print_flag = 1
train_and_fit_AE(lstm_width.to_unscaled(80),learning_rate.to_unscaled(0.003317))
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 16, 21)]          0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 80)                32640
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 16, 80)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 16, 80)            51520
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 16, 21)            8568
# =================================================================
# Total params: 92,728
# Trainable params: 92,728
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 4162 samples, validate on 463 samples
# Epoch 1/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.3451
# Epoch 00001: val_loss improved from inf to 0.26597, saving model to ./data/case_3.317e-03_80_best_model_ae-lstm.h5
# 4162/4162 [==============================] - 5s 1ms/sample - loss: 0.3431 - val_loss: 0.2660
# Epoch 2/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2618
# Epoch 00002: val_loss improved from 0.26597 to 0.23573, saving model to ./data/case_3.317e-03_80_best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 191us/sample - loss: 0.2605 - val_loss: 0.2357
# Epoch 3/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2437
# Epoch 00003: val_loss improved from 0.23573 to 0.22023, saving model to ./data/case_3.317e-03_80_best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 190us/sample - loss: 0.2428 - val_loss: 0.2202
# Epoch 4/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2306
# Epoch 00004: val_loss improved from 0.22023 to 0.20998, saving model to ./data/case_3.317e-03_80_best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 193us/sample - loss: 0.2300 - val_loss: 0.2100
# Epoch 5/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2199
# Epoch 00005: val_loss improved from 0.20998 to 0.19864, saving model to ./data/case_3.317e-03_80_best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 191us/sample - loss: 0.2196 - val_loss: 0.1986
# Epoch 6/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2166
# Epoch 00006: val_loss improved from 0.19864 to 0.19634, saving model to ./data/case_3.317e-03_80_best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 193us/sample - loss: 0.2166 - val_loss: 0.1963
# Epoch 7/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2127
# Epoch 00007: val_loss improved from 0.19634 to 0.19102, saving model to ./data/case_3.317e-03_80_best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 191us/sample - loss: 0.2124 - val_loss: 0.1910
# Epoch 8/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2060
# Epoch 00008: val_loss improved from 0.19102 to 0.18644, saving model to ./data/case_3.317e-03_80_best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 190us/sample - loss: 0.2073 - val_loss: 0.1864
# Epoch 9/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2055
# Epoch 00009: val_loss improved from 0.18644 to 0.18413, saving model to ./data/case_3.317e-03_80_best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 190us/sample - loss: 0.2051 - val_loss: 0.1841
# Epoch 10/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2028
# Epoch 00010: val_loss did not improve from 0.18413
# 4162/4162 [==============================] - 1s 172us/sample - loss: 0.2033 - val_loss: 0.1848
# Epoch 11/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.2000
# Epoch 00011: val_loss improved from 0.18413 to 0.18236, saving model to ./data/case_3.317e-03_80_best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 192us/sample - loss: 0.2001 - val_loss: 0.1824
# Epoch 12/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.1987
# Epoch 00012: val_loss improved from 0.18236 to 0.18187, saving model to ./data/case_3.317e-03_80_best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 193us/sample - loss: 0.1992 - val_loss: 0.1819
# Epoch 13/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.1986
# Epoch 00013: val_loss improved from 0.18187 to 0.17984, saving model to ./data/case_3.317e-03_80_best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 189us/sample - loss: 0.1981 - val_loss: 0.1798
# Epoch 14/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.1975
# Epoch 00014: val_loss improved from 0.17984 to 0.17900, saving model to ./data/case_3.317e-03_80_best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 191us/sample - loss: 0.1980 - val_loss: 0.1790
# Epoch 15/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.1952
# Epoch 00015: val_loss did not improve from 0.17900
# 4162/4162 [==============================] - 1s 175us/sample - loss: 0.1956 - val_loss: 0.1803
# Epoch 16/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.1947
# Epoch 00016: val_loss did not improve from 0.17900
# 4162/4162 [==============================] - 1s 172us/sample - loss: 0.1956 - val_loss: 0.1790
# Epoch 17/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.1953
# Epoch 00017: val_loss improved from 0.17900 to 0.17831, saving model to ./data/case_3.317e-03_80_best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 191us/sample - loss: 0.1953 - val_loss: 0.1783
# Epoch 18/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.1948
# Epoch 00018: val_loss improved from 0.17831 to 0.17644, saving model to ./data/case_3.317e-03_80_best_model_ae-lstm.h5
# 4162/4162 [==============================] - 1s 193us/sample - loss: 0.1950 - val_loss: 0.1764
# Epoch 19/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.1945
# Epoch 00019: val_loss did not improve from 0.17644
# 4162/4162 [==============================] - 1s 173us/sample - loss: 0.1941 - val_loss: 0.1793
# Epoch 20/20
# 3968/4162 [===========================>..] - ETA: 0s - loss: 0.1938
# Epoch 00020: val_loss did not improve from 0.17644
# 4162/4162 [==============================] - 1s 172us/sample - loss: 0.1931 - val_loss: 0.1769
#
# | Iteration | lstm width | learning rate |   loss | objective | trainable | non trainable | run time (mins) |
# |-----------------------------------------------------------------------------------------------------------|
# |         1 |         80 |      0.003317 | 0.1769 |    0.5348 |     92728 |             0 |          0.3350 |
# 0.5347939402453705

# %% [markdown]
# Now, let's the define Bayesian Optimization environment using the our model function:

# %%
optimizer = BayesianOptimization(
    f=train_and_fit_AE,
    pbounds=pbounds,
    verbose=0, # verbose = 1 prints only when a maximum is observed, verbose = 0 is silent
    random_state=1,
)

# %% [markdown]
# ### Main call to optimizer
# Run the optimizer to explore the parameter space. Each call to the method can take a few minutes. So the total time is almost 15-20 minutes. How can this be improved ?
#
# Suggestions for  experimentation (outside of current DLI):
# * **init_points** specifies the initial number of calls to the **lstm_autoencoder** using random parameters. This is used to get initial values to populate our search space. This can be done in parallel.
# * **n_iter** specifies the subsequent number of steps to leverage the prior results to search through new architectures using the most optimal possible parameters.  This is where we leverage Bayesian Optimization to optimize our model.

# %%
print_flag = 0
iter_history = []

init_points = 8 
num_steps = 8 

optimizer.maximize(
    init_points=init_points,
    n_iter=num_steps,
)
# Out:
# | Iteration | lstm width | learning rate |   loss | objective | trainable | non trainable | run time (mins) |
# |-----------------------------------------------------------------------------------------------------------|
# |         1 |         68 |      0.022723 | 0.4968 |    0.0072 |     69304 |             0 |          0.3109 |
# |         2 |         32 |      0.002481 | 0.1817 |    0.5168 |     19768 |             0 |          0.3327 |
# |         3 |         44 |      0.000816 | 0.1932 |    0.4740 |     32824 |             0 |          0.3375 |
# |         4 |         50 |      0.003120 | 0.1829 |    0.5124 |     40648 |             0 |          0.3391 |
# |         5 |         68 |      0.008686 | 0.1973 |    0.4590 |     69304 |             0 |          0.3261 |
# |         6 |         68 |      0.018866 | 0.5182 |    0.0047 |     69304 |             0 |          0.3005 |
# |         7 |         50 |      0.052426 | 0.5337 |    0.0034 |     40648 |             0 |          0.3286 |
# |         8 |         32 |      0.017448 | 0.2064 |    0.4267 |     19768 |             0 |          0.3380 |
# |         9 |         68 |      0.003292 | 0.1809 |    0.5197 |     69304 |             0 |          0.3270 |
# |        10 |         32 |      0.006380 | 0.1900 |    0.4859 |     19768 |             0 |          0.3301 |
# |        11 |         68 |      0.000690 | 0.2007 |    0.4468 |     69304 |             0 |          0.3465 |
# |        12 |         86 |      0.002958 | 0.1786 |    0.5285 |    105736 |             0 |          0.3282 |
# |        13 |         98 |      0.000892 | 0.1793 |    0.5256 |    134344 |             0 |          0.3347 |
# |        14 |        110 |      0.002463 | 0.1794 |    0.5252 |    166408 |             0 |          0.3442 |
# |        15 |        116 |      0.000603 | 0.1887 |    0.4904 |    183736 |             0 |          0.3354 |
# |        16 |        116 |      0.010096 | 0.5133 |    0.0051 |    183736 |             0 |          0.3200 |

# %% [markdown]
# <br>
#
# ### Example output from optimization
#
# <img src="./images/optresult.png" alt="optresult"/>
#
# <!-- ![image.png](attachment:image.png) -->

# %% [markdown]
# <br>
#
# ### Processing the results
# Bayesian optimization has provided several options for improved architectures. Some of the architectures are similar while there are quite a few which are different. It is useful to sort the architectures and take a look at the best performing ones. The next few steps sort and plot the best architectures.
# #### Sort the architectures with loss
# <a name="a2"></a>

# %%
results_list = [cur_iter['objective'] for cur_iter in iter_history]

idx_sorted = sorted(range(len(results_list)), key=results_list.__getitem__)
min_res = results_list[idx_sorted[0]]
max_res = results_list[idx_sorted[-1]]

# %% [markdown]
# <a name="a3"></a>
# #### Plot the loss per epoch for the best three cases

# %%
plot_model_loss([idx_sorted[-1-i] for i in range(3)],"Best cases")
# Out:
#                     Best cases
# Model: "model_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_15 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# lstm_39 (LSTM)               (None, 86)                37152
# _________________________________________________________________
# repeat_vector_13 (RepeatVect (None, 16, 86)            0
# _________________________________________________________________
# lstm_40 (LSTM)               (None, 16, 86)            59512
# _________________________________________________________________
# lstm_41 (LSTM)               (None, 16, 21)            9072
# =================================================================
# Total params: 105,736
# Trainable params: 105,736
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# lstm_42 (LSTM)               (None, 98)                47040
# _________________________________________________________________
# repeat_vector_14 (RepeatVect (None, 16, 98)            0
# _________________________________________________________________
# lstm_43 (LSTM)               (None, 16, 98)            77224
# _________________________________________________________________
# lstm_44 (LSTM)               (None, 16, 21)            10080
# =================================================================
# Total params: 134,344
# Trainable params: 134,344
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# lstm_45 (LSTM)               (None, 110)               58080
# _________________________________________________________________
# repeat_vector_15 (RepeatVect (None, 16, 110)           0
# _________________________________________________________________
# lstm_46 (LSTM)               (None, 16, 110)           97240
# _________________________________________________________________
# lstm_47 (LSTM)               (None, 16, 21)            11088
# =================================================================
# Total params: 166,408
# Trainable params: 166,408
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <br>
# **An example loss curve for a good architecture**
# ![Loss example 1](./images/loss_crv_ex1.png)

# %% [markdown]
# <a name="a4"></a>
# #### Plot the loss per epoch for the worst three cases

# %%
plot_model_loss([idx_sorted[i] for i in range(3)],"Worst cases")
# Out:
#                     Worst cases
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# lstm_24 (LSTM)               (None, 50)                14400
# _________________________________________________________________
# repeat_vector_8 (RepeatVecto (None, 16, 50)            0
# _________________________________________________________________
# lstm_25 (LSTM)               (None, 16, 50)            20200
# _________________________________________________________________
# lstm_26 (LSTM)               (None, 16, 21)            6048
# =================================================================
# Total params: 40,648
# Trainable params: 40,648
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 16, 21)]          0
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 68)                24480
# _________________________________________________________________
# repeat_vector_7 (RepeatVecto (None, 16, 68)            0
# _________________________________________________________________
# lstm_22 (LSTM)               (None, 16, 68)            37264
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 16, 21)            7560
# =================================================================
# Total params: 69,304
# Trainable params: 69,304
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_19 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# lstm_51 (LSTM)               (None, 116)               64032
# _________________________________________________________________
# repeat_vector_17 (RepeatVect (None, 16, 116)           0
# _________________________________________________________________
# lstm_52 (LSTM)               (None, 16, 116)           108112
# _________________________________________________________________
# lstm_53 (LSTM)               (None, 16, 21)            11592
# =================================================================
# Total params: 183,736
# Trainable params: 183,736
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <br>
#
# **A typical loss curve for a bad architecture**
# ![Loss example 1](./images/loss_crv_ex2.png)

# %% [markdown]
# <a name="a5"></a>
# #### Plot different architectures in a 2D space representating the different architectures with the minimum loss as the size

# %%
plot_loss_map(results_list)

# %% [markdown]
# <br>
#
# **An example map for the loss with the inputs for the lstm autoencoder**
# ![Loss example 1](./images/loss_map.png)

# %% [markdown]
# <a name="e5"></a>
# ### Exercise 4: Update code to use specified validation data
#
# The test data can also be specified as a separate dataset rather than being specified as a fraction of the dataset. This is useful especially in situations where it is important to have a certain structure in the test data representative of the training dataset, rather than a randomly sampled section of the main dataset. **train_and_fit_AE** method needs to be specified.
#
# As an exercise, please update the <<< TO DO >>> below with the appropriate validation data using the test data set as the features and label.
#
# <a name="q1"></a>

# %%
import statistics
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

print_flag = 0 
iter_history = []

def train_and_fit_AE(param1, param2):
    
    time_start = time.time()
    autoencoder, filename, params  = lstm_autoencoder(data_shape, [param1, param2])
   
    # checkpoint
    checkpoint = ModelCheckpoint(data_dir+filename, monitor='val_loss', 
                                 verbose=print_flag, save_best_only=True, mode='min')
    es = EarlyStopping(patience=15, verbose=print_flag)

    optimizer = Adam(lr=params['learning_rate'])
    autoencoder.compile(optimizer=optimizer, loss='mae')

    history = autoencoder.fit(x_train, x_train, batch_size=params['batch_size'], epochs=params['num_epochs'], 
                              validation_data=(x_test, x_test), verbose=print_flag, callbacks=[es, checkpoint])
    
    loss = history.history["val_loss"][-1]
    if np.isnan(loss) : loss = 1e8
    result = np.exp(-20*loss**2) 

    print_history(len(iter_history), params, loss, result, 
                  count_params(autoencoder,"train"), 
                  count_params(autoencoder,"non_train"),
                  (time.time()-time_start)/60.0)
    iter_history.append({'objective':result, 'params': params, 'history':history.history, "model" : autoencoder})
        
    return result

# %%
optimizer = BayesianOptimization(
    f=train_and_fit_AE,
    pbounds=pbounds,
    verbose=0, # verbose = 1 prints only when a maximum is observed, verbose = 0 is silent
    random_state=1,
)

print_flag = 0
iter_history = []

init_points = 8 
num_steps = 8 

optimizer.maximize(
    init_points=init_points,
    n_iter=num_steps,
)
# Out:
# | Iteration | lstm width | learning rate |   loss | objective | trainable | non trainable | run time (mins) |
# |-----------------------------------------------------------------------------------------------------------|
# |         1 |         68 |      0.022723 | 0.5225 |    0.0042 |     69304 |             0 |          0.3797 |
# |         2 |         32 |      0.002481 | 0.2142 |    0.3996 |     19768 |             0 |          0.3635 |
# |         3 |         44 |      0.000816 | 0.2108 |    0.4113 |     32824 |             0 |          0.3703 |
# |         4 |         50 |      0.003120 | 0.2134 |    0.4023 |     40648 |             0 |          0.3632 |
# |         5 |         68 |      0.008686 | 0.2239 |    0.3669 |     69304 |             0 |          0.4071 |
# |         6 |         68 |      0.018866 | 0.5075 |    0.0058 |     69304 |             0 |          0.3472 |
# |         7 |         50 |      0.052426 | 0.5235 |    0.0042 |     40648 |             0 |          0.3381 |
# |         8 |         32 |      0.017448 | 0.5112 |    0.0054 |     19768 |             0 |          0.3800 |
# |         9 |         68 |      0.003076 | 0.2107 |    0.4116 |     69304 |             0 |          0.3582 |
# |        10 |         62 |      0.000693 | 0.2156 |    0.3947 |     58888 |             0 |          0.3644 |
# |        11 |         86 |      0.001175 | 0.2132 |    0.4029 |    105736 |             0 |          0.3631 |
# |        12 |         92 |      0.004267 | 0.2114 |    0.4090 |    119608 |             0 |          0.3882 |
# |        13 |        110 |      0.002021 | 0.2087 |    0.4184 |    166408 |             0 |          0.3577 |
# |        14 |        110 |      0.000500 | 0.2219 |    0.3737 |    166408 |             0 |          0.3695 |
# |        15 |        116 |      0.008993 | 0.3075 |    0.1509 |    183736 |             0 |          0.3552 |
# |        16 |         32 |      0.000500 | 0.2252 |    0.3626 |     19768 |             0 |          0.4009 |

# %% [markdown]
# <a name="e6"></a>
# ### Exercise 5: Create HPO result plots
# Now the results of this new hyperparameter optimization can be analyzed in a similar way as the previous particular dataset.
# * sort the architectures
# * loss vs epoch for best three architectures
# * loss vs epoch for worst three architectures
# * map of training and test loss with key parameters of the architectures - learning rate and lstm width
#
# The code required below is used from the plotting above. <br>
# Use the hyperlinks to go to the appropriate session and scroll down to this section to complete the exercise.

# %% [markdown]
# #### Sort the architectures with loss

# %%
results_list = [cur_iter['objective'] for cur_iter in iter_history]

idx_sorted = sorted(range(len(results_list)), key=results_list.__getitem__)
min_res = results_list[idx_sorted[0]]
max_res = results_list[idx_sorted[-1]]

# %% [markdown]
# **Plot the loss per epoch for the best three cases**

# %%
plot_model_loss([idx_sorted[-1-i] for i in range(3)],"Best cases")
# Out:
#                     Best cases
# Model: "model_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_32 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# lstm_90 (LSTM)               (None, 110)               58080
# _________________________________________________________________
# repeat_vector_30 (RepeatVect (None, 16, 110)           0
# _________________________________________________________________
# lstm_91 (LSTM)               (None, 16, 110)           97240
# _________________________________________________________________
# lstm_92 (LSTM)               (None, 16, 21)            11088
# =================================================================
# Total params: 166,408
# Trainable params: 166,408
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_28 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# lstm_78 (LSTM)               (None, 68)                24480
# _________________________________________________________________
# repeat_vector_26 (RepeatVect (None, 16, 68)            0
# _________________________________________________________________
# lstm_79 (LSTM)               (None, 16, 68)            37264
# _________________________________________________________________
# lstm_80 (LSTM)               (None, 16, 21)            7560
# =================================================================
# Total params: 69,304
# Trainable params: 69,304
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_22 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# lstm_60 (LSTM)               (None, 44)                11616
# _________________________________________________________________
# repeat_vector_20 (RepeatVect (None, 16, 44)            0
# _________________________________________________________________
# lstm_61 (LSTM)               (None, 16, 44)            15664
# _________________________________________________________________
# lstm_62 (LSTM)               (None, 16, 21)            5544
# =================================================================
# Total params: 32,824
# Trainable params: 32,824
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Plot the loss per epoch for the worst three cases**

# %%
plot_model_loss([idx_sorted[i] for i in range(3)],"Worst cases")
# Out:
#                     Worst cases
# Model: "model_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_26 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# lstm_72 (LSTM)               (None, 50)                14400
# _________________________________________________________________
# repeat_vector_24 (RepeatVect (None, 16, 50)            0
# _________________________________________________________________
# lstm_73 (LSTM)               (None, 16, 50)            20200
# _________________________________________________________________
# lstm_74 (LSTM)               (None, 16, 21)            6048
# =================================================================
# Total params: 40,648
# Trainable params: 40,648
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_20 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# lstm_54 (LSTM)               (None, 68)                24480
# _________________________________________________________________
# repeat_vector_18 (RepeatVect (None, 16, 68)            0
# _________________________________________________________________
# lstm_55 (LSTM)               (None, 16, 68)            37264
# _________________________________________________________________
# lstm_56 (LSTM)               (None, 16, 21)            7560
# =================================================================
# Total params: 69,304
# Trainable params: 69,304
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_27 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# lstm_75 (LSTM)               (None, 32)                6912
# _________________________________________________________________
# repeat_vector_25 (RepeatVect (None, 16, 32)            0
# _________________________________________________________________
# lstm_76 (LSTM)               (None, 16, 32)            8320
# _________________________________________________________________
# lstm_77 (LSTM)               (None, 16, 21)            4536
# =================================================================
# Total params: 19,768
# Trainable params: 19,768
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Plot different architectures in a 2D space representating the different architectures with the minimum loss as the size**

# %%
plot_loss_map(results_list)

# %% [markdown]
# ## Results of specifying a different validation dataset
# It is important to understand the role of data in prediction quality of models. In the first exercise of hyperparameter optimization, a fraction of the main dataset is used which is randomly sampled. In the second exercise of hyperparameter optimization, the test dataset for XGBoost in Lab1 is used. The distribution of the sensor data is different from the main dataset. A histogram of the both datasets is shown below.
# <br>
#
# This leads to the difference in training of the autoencoder models and the loss for each model and, eventually an impact on the direction of hyperparameter optimization.
#
# <img src="./images/histogram_lab1.png" alt="histogram lab 1" width="700"/>
#
# <br>
# <br>

# %% [markdown]
# ## Optional Exercise
#
# Update **train_and_fit_AE** to optimize the autoencoder based on 1D convolutions example discussed in this lab.
# * What are the key components to perform the hyperparameter optimization ?
# * What can be inputs to the optimization ?
# * How should the objective function be structured ?

# %% [markdown]
# **Exercise**: Define the method to create the autoencoder model with input parameters using tf.keras

# %%
# Model #2 -Conv1D-based Encoder-Decoder
data_shape = x_train.shape[1:]  

dp_lvl = 0.2

def conv1d_autoencoder(data_shape, params_list):
    
    
    mod_params = {} 
    mod_params['outside_filters'] = outside_filters.from_unscaled(int(np.round(params_list[0])))
    mod_params['inside_filters'] = inside_filters.from_unscaled(params_list[1])
    mod_params['learning_rate'] = learning_rate.from_unscaled(params_list[2])
    mod_params['dropout_rate'] = dropout_rate.from_unscaled(params_list[3])
    mod_params['num_epochs'] = 20
    mod_params['batch_size'] = 128 
    #convert from unscaled inputs provided by optimizer using params_list 
    
    inputs = Input(shape=(data_shape))
    ksize=6

    # --- Encode ---
    encoded = Conv1D(filters=mod_params['outside_filters'], kernel_size=ksize, activation="relu", padding="same")(inputs)
    encoded = MaxPooling1D(pool_size=2)(encoded)
    encoded = Dropout(rate=mod_params['dropout_rate'])(encoded)
    encoded = Conv1D(filters=mod_params['inside_filters'], kernel_size=ksize, activation="relu", padding="same")(encoded)
    encoded = MaxPooling1D(pool_size=2)(encoded)
    encoded = Dropout(rate=mod_params['dropout_rate'])(encoded)
    # --- Encodings ---
    encoded = Conv1D(filters=4, kernel_size=ksize, activation="relu", padding="same")(encoded)
    encoded = Dropout(rate=mod_params['dropout_rate'])(encoded)
    # --- Decode ---
    decoded = UpSampling1D(size=2)(encoded)
    decoded = Conv1D(filters=mod_params['inside_filters'], kernel_size=ksize, activation="relu", padding="same")(decoded)
    decoded = Dropout(rate=mod_params['dropout_rate'])(decoded)
    decoded = UpSampling1D(size=2)(decoded)
    decoded = Conv1D(filters=mod_params['outside_filters'], kernel_size=ksize, activation="relu", padding="same")(decoded)
    decoded = Dropout(rate=mod_params['dropout_rate'])(decoded)
    # --- Output ---
    output_layer = Conv1D(filters=data_shape[1], kernel_size=1, activation="linear", padding="same")(decoded)

    autoencoder = Model(inputs, output_layer )
    autoencoder.compile(optimizer = "adam", loss = "mse", metrics = ["accuracy"])
    
    # provide an output filename for storing model weights for lowest loss for the current architecture
    filename = "case_%.3e_%.3e_%d_%d_best_model_ae-conv1d.h5" %  \
                                 (mod_params["learning_rate"],mod_params["dropout_rate"], \
                                  mod_params["outside_filters"],mod_params["inside_filters"])
    
    if print_flag == 1:
        print(autoencoder.summary())
    return autoencoder, filename, mod_params

# %% [markdown]
# **Exercise**: Define the method to create the autoencoder model with input parameters using tf.keras. No change in needed but the cell below must be run

# %%
print_flag = 0 
iter_history = []

def train_and_fit_AE(param1, param2, param3, param4):
    
    time_start = time.time()
    autoencoder, filename, params  = conv1d_autoencoder(data_shape, [param1, param2, param3, param4])
   
    # checkpoint
    checkpoint = ModelCheckpoint(data_dir+filename, monitor='val_loss', 
                                 verbose=print_flag, save_best_only=True, mode='min')
    es = EarlyStopping(patience=15, verbose=print_flag)

    optimizer = Adam(lr=params['learning_rate'])
    autoencoder.compile(optimizer=optimizer, loss='mse')

    history = autoencoder.fit(x_train, x_train, batch_size=params['batch_size'], epochs=params['num_epochs'], 
                              validation_split=0.1, verbose=print_flag, callbacks=[es, checkpoint])
    loss = history.history["val_loss"][-1]
    if np.isnan(loss) : loss = 1e8
    result = np.exp(-20*loss**2) 

    print_history(len(iter_history), params, loss, result, 
                  count_params(autoencoder,"train"), 
                  count_params(autoencoder,"non_train"),
                  (time.time()-time_start)/60.0)
    iter_history.append({'objective':result, 'params': params, 'history':history.history, "model" : autoencoder})
        
    return result

# %% [markdown]
# **Exercise**: Define the method to create the autoencoder model with input parameters using tf.keras

# %%
outside_filters = Hyperparameter({"min": 32, "max": 196, "count": 15, "type" : "int" })
inside_filters = Hyperparameter({"min": 32, "max": 196, "count": 15, "type" : "int" })

learning_rate = Hyperparameter({"min": 0.0005, "max": 0.1, "count": 15, "scale" : "log"})
dropout_rate = Hyperparameter({"min": 0.0005, "max": 0.1, "count": 15, "scale" : "log"})


pbounds = {"param1" : (0,outside_filters.count-1),
           "param2"  : (0,inside_filters.count-1), 
           "param3"   : (0,learning_rate.count-1), 
           "param4"    : (0,dropout_rate.count-1), 
          }
# Out:
#  Hyperparameter (min: 32, max: 196, scale: linear, step: 11, count: 15, type: int)
#  Hyperparameter (min: 32, max: 196, scale: linear, step: 11, count: 15, type: int)
#  Hyperparameter (min: 0.0005, max: 0.1, scale: log, step: 0.37845124046771694, count: 15, type: float)
#  Hyperparameter (min: 0.0005, max: 0.1, scale: log, step: 0.37845124046771694, count: 15, type: float)

# %%
def print_history(num_step, mod_params, loss, result, num_train, num_non_train, run_time):

    if num_step == 0: 
        print("\n| {:>4s} | {:>8s} | {:>8s} | {:>13s} | {:>7s} | {:>6s} | {:>9s} | {:>9s} | {:>13s} | {:>7s} | \n|".format("Iter",
                                                                         "out filt", "in filt",
                                                                         "learning rate", "dropout",
                                                                         "loss","objective", "trainable", "non trainable",
                                                                         "t (min)")+'-'*113+"|")
        
    print( "| {:>4d} | {:>8d} | {:>8d} | {:>13.4g} | {:>7.3g} | {:>6.4f} | {:>9.4f} | {:>9d} | {:>13d} | {:>7.2f} |".format( num_step + 1,
        mod_params['outside_filters'],mod_params['inside_filters'],mod_params['learning_rate'],mod_params['dropout_rate'],
        loss, result, num_train, num_non_train, run_time))

# %%
def plot_history(history,result,oflt,iflt,lr,dr):
    plt.figure()
    plt.plot(history['loss'],'g')
    plt.plot(history['val_loss'],'r')

    plt.ylabel('Loss')
    plt.xlabel('# epoch')
    plt.legend(['train', 'test'], loc='lower right')
    plt.ylim([0.1,0.9])
    plt.title("Conv1D Loss across epochs \n outside filters {:7d} inside filters {:7d} \n learning rate {:7.4f} dropout rate {:7.4f}  \n objective {:7.4f}" .format(oflt,iflt,lr,dr,result))

# %%
def plot_model_loss(idx_list,header): 
    
    print(" "*20 + header)
    for idx in idx_list:
        cur_iter = iter_history[idx]
        iter_history[idx]["model"].summary()
        plot_history(cur_iter["history"],cur_iter['objective'],
                     cur_iter['params']['outside_filters'],cur_iter['params']['inside_filters'],
                     cur_iter['params']['learning_rate'],cur_iter['params']['dropout_rate'])

# %%
def plot_loss_map(results_list):
    results_list_shifted = [r - 0.9*min_res for r in results_list]
    plt.figure(figsize=(6,4))
    plt.scatter([c['params']['outside_filters'] for c in iter_history],
                [c['params']['learning_rate'] for c in iter_history],
                s=[r*500 for r in results_list_shifted],
                c=[r for r in results_list_shifted ])

    for i,c in enumerate(iter_history):
        plt.text(c['params']['outside_filters'], c['params']['learning_rate'], r'%d'%(i),fontsize = 14)
    plt.xlabel('outside_filters',fontsize=14)
    plt.ylabel('learning_rate',fontsize=14)
    plt.tick_params(labelsize=12)
    plt.yscale('log')

# %% [markdown]
# **Exercise**: Define the method to create the autoencoder model with input parameters using tf.keras

# %%
print_flag = 1
train_and_fit_AE(outside_filters.to_unscaled(160),
                 inside_filters.to_unscaled(80),
                 learning_rate.to_unscaled(.005),
                 dropout_rate.to_unscaled(.1))
# Out:
# Model: "model_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_36 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 16, 153)           19431
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 8, 153)            0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 8, 153)            0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 8, 76)             69844
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 4, 76)             0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 4, 76)             0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 4, 4)              1828
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 4, 4)              0
# _________________________________________________________________
# up_sampling1d_2 (UpSampling1 (None, 8, 4)              0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 8, 76)             1900
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 8, 76)             0
# _________________________________________________________________
# up_sampling1d_3 (UpSampling1 (None, 16, 76)            0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 16, 153)           69921
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 16, 153)           0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 16, 21)            3234
# =================================================================
# Total params: 166,158
# Trainable params: 166,158
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 4162 samples, validate on 463 samples
# Epoch 1/20
# 2944/4162 [====================>.........] - ETA: 0s - loss: 0.9336
# Epoch 00001: val_loss improved from inf to 0.49066, saving model to ./data/case_5.000e-03_1.000e-01_153_76_best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 1s 342us/sample - loss: 0.9002 - val_loss: 0.4907
# Epoch 2/20
# 3712/4162 [=========================>....] - ETA: 0s - loss: 0.8147
# Epoch 00002: val_loss improved from 0.49066 to 0.43925, saving model to ./data/case_5.000e-03_1.000e-01_153_76_best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 58us/sample - loss: 0.8011 - val_loss: 0.4392
# Epoch 3/20
# 3584/4162 [========================>.....] - ETA: 0s - loss: 0.8096
# Epoch 00003: val_loss improved from 0.43925 to 0.43651, saving model to ./data/case_5.000e-03_1.000e-01_153_76_best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 57us/sample - loss: 0.7617 - val_loss: 0.4365
# Epoch 4/20
# 3712/4162 [=========================>....] - ETA: 0s - loss: 0.7611
# Epoch 00004: val_loss improved from 0.43651 to 0.40809, saving model to ./data/case_5.000e-03_1.000e-01_153_76_best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 57us/sample - loss: 0.7257 - val_loss: 0.4081
# Epoch 5/20
# 3584/4162 [========================>.....] - ETA: 0s - loss: 0.6857
# Epoch 00005: val_loss improved from 0.40809 to 0.39459, saving model to ./data/case_5.000e-03_1.000e-01_153_76_best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 57us/sample - loss: 0.7113 - val_loss: 0.3946
# Epoch 6/20
# 3712/4162 [=========================>....] - ETA: 0s - loss: 0.7437
# Epoch 00006: val_loss did not improve from 0.39459
# 4162/4162 [==============================] - 0s 34us/sample - loss: 0.7046 - val_loss: 0.4349
# Epoch 7/20
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.5889
# Epoch 00007: val_loss did not improve from 0.39459
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.7094 - val_loss: 0.4274
# Epoch 8/20
# 3712/4162 [=========================>....] - ETA: 0s - loss: 0.6344
# Epoch 00008: val_loss did not improve from 0.39459
# 4162/4162 [==============================] - 0s 34us/sample - loss: 0.7013 - val_loss: 0.4165
# Epoch 9/20
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.7227
# Epoch 00009: val_loss improved from 0.39459 to 0.39125, saving model to ./data/case_5.000e-03_1.000e-01_153_76_best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 57us/sample - loss: 0.7234 - val_loss: 0.3912
# Epoch 10/20
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.7506
# Epoch 00010: val_loss did not improve from 0.39125
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.7538 - val_loss: 0.4936
# Epoch 11/20
# 3584/4162 [========================>.....] - ETA: 0s - loss: 0.7758
# Epoch 00011: val_loss did not improve from 0.39125
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.7467 - val_loss: 0.4067
# Epoch 12/20
# 3712/4162 [=========================>....] - ETA: 0s - loss: 0.6415
# Epoch 00012: val_loss did not improve from 0.39125
# 4162/4162 [==============================] - 0s 34us/sample - loss: 0.7150 - val_loss: 0.4672
# Epoch 13/20
# 3584/4162 [========================>.....] - ETA: 0s - loss: 0.6276
# Epoch 00013: val_loss improved from 0.39125 to 0.39032, saving model to ./data/case_5.000e-03_1.000e-01_153_76_best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 57us/sample - loss: 0.7261 - val_loss: 0.3903
# Epoch 14/20
# 3712/4162 [=========================>....] - ETA: 0s - loss: 0.7007
# Epoch 00014: val_loss improved from 0.39032 to 0.38753, saving model to ./data/case_5.000e-03_1.000e-01_153_76_best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 61us/sample - loss: 0.6729 - val_loss: 0.3875
# Epoch 15/20
# 3712/4162 [=========================>....] - ETA: 0s - loss: 0.6932
# Epoch 00015: val_loss did not improve from 0.38753
# 4162/4162 [==============================] - 0s 34us/sample - loss: 0.6961 - val_loss: 0.3930
# Epoch 16/20
# 3456/4162 [=======================>......] - ETA: 0s - loss: 0.7468
# Epoch 00016: val_loss did not improve from 0.38753
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.6814 - val_loss: 0.3910
# Epoch 17/20
# 3712/4162 [=========================>....] - ETA: 0s - loss: 0.6869
# Epoch 00017: val_loss improved from 0.38753 to 0.35594, saving model to ./data/case_5.000e-03_1.000e-01_153_76_best_model_ae-conv1d.h5
# 4162/4162 [==============================] - 0s 57us/sample - loss: 0.6900 - val_loss: 0.3559
# Epoch 18/20
# 3584/4162 [========================>.....] - ETA: 0s - loss: 0.6796
# Epoch 00018: val_loss did not improve from 0.35594
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.6706 - val_loss: 0.3695
# Epoch 19/20
# 3712/4162 [=========================>....] - ETA: 0s - loss: 0.7037
# Epoch 00019: val_loss did not improve from 0.35594
# 4162/4162 [==============================] - 0s 34us/sample - loss: 0.6701 - val_loss: 0.3707
# Epoch 20/20
# 3584/4162 [========================>.....] - ETA: 0s - loss: 0.6150
# Epoch 00020: val_loss did not improve from 0.35594
# 4162/4162 [==============================] - 0s 35us/sample - loss: 0.6543 - val_loss: 0.3644
#
# | Iter | out filt |  in filt | learning rate | dropout |   loss | objective | trainable | non trainable | t (min) |
# |-----------------------------------------------------------------------------------------------------------------|
# |    1 |      153 |       76 |         0.005 |     0.1 | 0.3644 |    0.0702 |    166158 |             0 |    0.09 |
# 0.07019531763120831

# %% [markdown]
# #### Define the optimizer using the new method to call Conv1d based autoencoder

# %%
pbounds
# Out:
# {'param1': (0, 14), 'param2': (0, 14), 'param3': (0, 14), 'param4': (0, 14)}

# %%
optimizer = BayesianOptimization(
    f=train_and_fit_AE,
    pbounds=pbounds,
    verbose=0, # verbose = 1 prints only when a maximum is observed, verbose = 0 is silent
    random_state=1,
)

# %% [markdown]
# #### Run optimization

# %%
print_flag = 0
iter_history = []

init_points = 8 
num_steps = 8 

optimizer.maximize(
    init_points=init_points,
    n_iter=num_steps,
)
# Out:
# | Iter | out filt |  in filt | learning rate | dropout |   loss | objective | trainable | non trainable | t (min) |
# |-----------------------------------------------------------------------------------------------------------------|
# |    1 |       98 |      142 |     0.0005003 | 0.00248 | 0.1349 |    0.6950 |    188719 |             0 |    0.10 |
# |    2 |       54 |       46 |      0.001341 | 0.00312 | 0.1284 |    0.7193 |     40179 |             0 |    0.09 |
# |    3 |       98 |      114 |      0.004608 |  0.0189 | 0.2267 |    0.3576 |    154391 |             0 |    0.09 |
# |    4 |       65 |      167 |     0.0005781 |  0.0174 | 0.1675 |    0.5704 |    148320 |             0 |    0.10 |
# |    5 |       98 |      118 |      0.001052 | 0.00143 | 0.1185 |    0.7551 |    159295 |             0 |    0.09 |
# |    6 |      153 |      181 |      0.002631 |  0.0196 | 0.1903 |    0.4848 |    364188 |             0 |    0.10 |
# |    7 |      164 |      169 |     0.0007846 | 0.000615 | 0.1136 |    0.7725 |    365503 |             0 |    0.10 |
# |    8 |       54 |      167 |     0.0008419 | 0.00466 | 0.1407 |    0.6732 |    124637 |             0 |    0.09 |
# |    9 |       32 |      105 |        0.0005 |  0.0005 | 0.1864 |    0.4993 |     50363 |             0 |    0.09 |
# |   10 |      131 |      132 |     0.0009408 |  0.0005 | 0.1176 |    0.7585 |    233648 |             0 |    0.10 |
# |   11 |      109 |      186 |      0.001916 |  0.0005 | 0.1659 |    0.5765 |    268854 |             0 |    0.09 |
# |   12 |      186 |      125 |        0.0005 | 0.000764 | 0.1338 |    0.6989 |    312989 |             0 |    0.10 |
# |   13 |      120 |       73 |     0.0006664 | 0.000947 | 0.1474 |    0.6475 |    126675 |             0 |    0.09 |
# |   14 |      186 |      145 |      0.003075 |  0.0005 | 0.1954 |    0.4658 |    358629 |             0 |    0.09 |
# |   15 |      142 |      151 |        0.0005 | 0.000988 | 0.1170 |    0.7605 |    286037 |             0 |    0.10 |
# |   16 |      109 |      129 |        0.0005 |  0.0005 | 0.1287 |    0.7180 |    191448 |             0 |    0.10 |

# %% [markdown]
# #### Sort architectures

# %%
results_list = [cur_iter['objective'] for cur_iter in iter_history]

idx_sorted = sorted(range(len(results_list)), key=results_list.__getitem__)
min_res = results_list[idx_sorted[0]]
max_res = results_list[idx_sorted[-1]]

# %% [markdown]
# **Plot the loss per epoch for the best three cases**

# %%
plot_model_loss([idx_sorted[-1-i] for i in range(3)],"Best cases")
# Out:
#                     Best cases
# Model: "model_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_43 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# conv1d_48 (Conv1D)           (None, 16, 164)           20828
# _________________________________________________________________
# max_pooling1d_16 (MaxPooling (None, 8, 164)            0
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 8, 164)            0
# _________________________________________________________________
# conv1d_49 (Conv1D)           (None, 8, 169)            166465
# _________________________________________________________________
# max_pooling1d_17 (MaxPooling (None, 4, 169)            0
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 4, 169)            0
# _________________________________________________________________
# conv1d_50 (Conv1D)           (None, 4, 4)              4060
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 4, 4)              0
# _________________________________________________________________
# up_sampling1d_16 (UpSampling (None, 8, 4)              0
# _________________________________________________________________
# conv1d_51 (Conv1D)           (None, 8, 169)            4225
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 8, 169)            0
# _________________________________________________________________
# up_sampling1d_17 (UpSampling (None, 16, 169)           0
# _________________________________________________________________
# conv1d_52 (Conv1D)           (None, 16, 164)           166460
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 16, 164)           0
# _________________________________________________________________
# conv1d_53 (Conv1D)           (None, 16, 21)            3465
# =================================================================
# Total params: 365,503
# Trainable params: 365,503
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_50"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_51 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# conv1d_96 (Conv1D)           (None, 16, 142)           18034
# _________________________________________________________________
# max_pooling1d_32 (MaxPooling (None, 8, 142)            0
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 8, 142)            0
# _________________________________________________________________
# conv1d_97 (Conv1D)           (None, 8, 151)            128803
# _________________________________________________________________
# max_pooling1d_33 (MaxPooling (None, 4, 151)            0
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 4, 151)            0
# _________________________________________________________________
# conv1d_98 (Conv1D)           (None, 4, 4)              3628
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 4, 4)              0
# _________________________________________________________________
# up_sampling1d_32 (UpSampling (None, 8, 4)              0
# _________________________________________________________________
# conv1d_99 (Conv1D)           (None, 8, 151)            3775
# _________________________________________________________________
# dropout_83 (Dropout)         (None, 8, 151)            0
# _________________________________________________________________
# up_sampling1d_33 (UpSampling (None, 16, 151)           0
# _________________________________________________________________
# conv1d_100 (Conv1D)          (None, 16, 142)           128794
# _________________________________________________________________
# dropout_84 (Dropout)         (None, 16, 142)           0
# _________________________________________________________________
# conv1d_101 (Conv1D)          (None, 16, 21)            3003
# =================================================================
# Total params: 286,037
# Trainable params: 286,037
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_45"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_46 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# conv1d_66 (Conv1D)           (None, 16, 131)           16637
# _________________________________________________________________
# max_pooling1d_22 (MaxPooling (None, 8, 131)            0
# _________________________________________________________________
# dropout_55 (Dropout)         (None, 8, 131)            0
# _________________________________________________________________
# conv1d_67 (Conv1D)           (None, 8, 132)            103884
# _________________________________________________________________
# max_pooling1d_23 (MaxPooling (None, 4, 132)            0
# _________________________________________________________________
# dropout_56 (Dropout)         (None, 4, 132)            0
# _________________________________________________________________
# conv1d_68 (Conv1D)           (None, 4, 4)              3172
# _________________________________________________________________
# dropout_57 (Dropout)         (None, 4, 4)              0
# _________________________________________________________________
# up_sampling1d_22 (UpSampling (None, 8, 4)              0
# _________________________________________________________________
# conv1d_69 (Conv1D)           (None, 8, 132)            3300
# _________________________________________________________________
# dropout_58 (Dropout)         (None, 8, 132)            0
# _________________________________________________________________
# up_sampling1d_23 (UpSampling (None, 16, 132)           0
# _________________________________________________________________
# conv1d_70 (Conv1D)           (None, 16, 131)           103883
# _________________________________________________________________
# dropout_59 (Dropout)         (None, 16, 131)           0
# _________________________________________________________________
# conv1d_71 (Conv1D)           (None, 16, 21)            2772
# =================================================================
# Total params: 233,648
# Trainable params: 233,648
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Plot the loss per epoch for the worst three cases**

# %%
plot_model_loss([idx_sorted[i] for i in range(3)],"Worst cases")
# Out:
#                     Worst cases
# Model: "model_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_39 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# conv1d_24 (Conv1D)           (None, 16, 98)            12446
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 8, 98)             0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 8, 98)             0
# _________________________________________________________________
# conv1d_25 (Conv1D)           (None, 8, 114)            67146
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 4, 114)            0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 4, 114)            0
# _________________________________________________________________
# conv1d_26 (Conv1D)           (None, 4, 4)              2740
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 4, 4)              0
# _________________________________________________________________
# up_sampling1d_8 (UpSampling1 (None, 8, 4)              0
# _________________________________________________________________
# conv1d_27 (Conv1D)           (None, 8, 114)            2850
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 8, 114)            0
# _________________________________________________________________
# up_sampling1d_9 (UpSampling1 (None, 16, 114)           0
# _________________________________________________________________
# conv1d_28 (Conv1D)           (None, 16, 98)            67130
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 16, 98)            0
# _________________________________________________________________
# conv1d_29 (Conv1D)           (None, 16, 21)            2079
# =================================================================
# Total params: 154,391
# Trainable params: 154,391
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_49"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_50 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# conv1d_90 (Conv1D)           (None, 16, 186)           23622
# _________________________________________________________________
# max_pooling1d_30 (MaxPooling (None, 8, 186)            0
# _________________________________________________________________
# dropout_75 (Dropout)         (None, 8, 186)            0
# _________________________________________________________________
# conv1d_91 (Conv1D)           (None, 8, 145)            161965
# _________________________________________________________________
# max_pooling1d_31 (MaxPooling (None, 4, 145)            0
# _________________________________________________________________
# dropout_76 (Dropout)         (None, 4, 145)            0
# _________________________________________________________________
# conv1d_92 (Conv1D)           (None, 4, 4)              3484
# _________________________________________________________________
# dropout_77 (Dropout)         (None, 4, 4)              0
# _________________________________________________________________
# up_sampling1d_30 (UpSampling (None, 8, 4)              0
# _________________________________________________________________
# conv1d_93 (Conv1D)           (None, 8, 145)            3625
# _________________________________________________________________
# dropout_78 (Dropout)         (None, 8, 145)            0
# _________________________________________________________________
# up_sampling1d_31 (UpSampling (None, 16, 145)           0
# _________________________________________________________________
# conv1d_94 (Conv1D)           (None, 16, 186)           162006
# _________________________________________________________________
# dropout_79 (Dropout)         (None, 16, 186)           0
# _________________________________________________________________
# conv1d_95 (Conv1D)           (None, 16, 21)            3927
# =================================================================
# Total params: 358,629
# Trainable params: 358,629
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_42 (InputLayer)        [(None, 16, 21)]          0
# _________________________________________________________________
# conv1d_42 (Conv1D)           (None, 16, 153)           19431
# _________________________________________________________________
# max_pooling1d_14 (MaxPooling (None, 8, 153)            0
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 8, 153)            0
# _________________________________________________________________
# conv1d_43 (Conv1D)           (None, 8, 181)            166339
# _________________________________________________________________
# max_pooling1d_15 (MaxPooling (None, 4, 181)            0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 4, 181)            0
# _________________________________________________________________
# conv1d_44 (Conv1D)           (None, 4, 4)              4348
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 4, 4)              0
# _________________________________________________________________
# up_sampling1d_14 (UpSampling (None, 8, 4)              0
# _________________________________________________________________
# conv1d_45 (Conv1D)           (None, 8, 181)            4525
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 8, 181)            0
# _________________________________________________________________
# up_sampling1d_15 (UpSampling (None, 16, 181)           0
# _________________________________________________________________
# conv1d_46 (Conv1D)           (None, 16, 153)           166311
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 16, 153)           0
# _________________________________________________________________
# conv1d_47 (Conv1D)           (None, 16, 21)            3234
# =================================================================
# Total params: 364,188
# Trainable params: 364,188
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Plot different architectures in a 2D space representating the different architectures with the minimum loss as the size**

# %%
plot_loss_map(results_list)

# %% [markdown]
# ## Summary

# %% [markdown]
# In this course, we tackled the predictive maintenance problem using different approaches. Mainly, we used a machine-learning-based approach called XGBoost to classify the defective hard drive samples. Next, we used recurrent neural networks to predict hard drive feature sequences and indicate whether the timeseries ends in a fail state or not. Finally, we used an anomaly detection approach to classify samples into defective/normal bins.
# One important factor affecting the outcome of all the models experimented in this course, is the number of data sequences. While we had the liberty of choosing among a dataset of 6M samples, the defective hard drives were significantly less. This challenge affected the outcome of the models discussed so far. To overcome similar issues in industrial applications, the reader is encouraged to investigate data augmentation techniques to increase the training set.
